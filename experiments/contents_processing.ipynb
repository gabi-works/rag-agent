# %%
import os
import re
import sys
import glob
import json
import pymupdf
from pathlib import Path

# %%
API_SPEC_PATH = "../pdfs/api_specification.pdf"
GUIDELINE_PATH = "../pdfs/guideline.pdf"

SPLITTED_PDF_PATH = "../pdfs/splitted"
ANALYZED_JSON_PATH = "../analyzed_jsons"
CROPPED_RESOURCES_PATH = "../cropped_pdf_resources"

# %%
sys.path.append(os.path.abspath('../'))

# %%
from src.ingestion.states import FileState

# %%
def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', s)]

# %%
def extract_page_elements(file_basename):
    file_paths = glob.glob(os.path.join(ANALYZED_JSON_PATH, file_basename, file_basename + "*"))
    sorted_file_paths = sorted(file_paths, key=natural_sort_key)
    page_elements = dict()

    element_id = 0

    for fp in sorted_file_paths:
        with open(fp, "r") as f:
            data = json.load(f)

        for element in data["elements"]:
            num_page = int(Path(fp).stem.split("_")[-1])

            if num_page not in page_elements:
                page_elements[num_page] = []
            
            element["id"] = element_id
            element_id += 1

            element["page"] = num_page

            page_elements[num_page].append(element)
    
    sorted_page_elements = dict(sorted(page_elements.items()))
    return sorted_page_elements

# %%
guideline_page_elements = extract_page_elements("guideline")

# %%
def extract_page_size(file_basename, page_metadata):
    file_paths = glob.glob(os.path.join(ANALYZED_JSON_PATH, file_basename, file_basename + "*"))

    for fp in file_paths:
        with open(fp, "r") as f:
            page_data = json.load(f)
    
            num_page = int(Path(fp).stem.split("_")[-1])

            for element in page_data["metadata"]["pages"]:
                metadata = {
                    "size" : [
                        int(element["width"]),
                        int(element["height"]),
                    ],
                }
                
                page_metadata[num_page] = metadata
    
    sorted_page_metadata = dict(sorted(page_metadata.items()))         
    return sorted_page_metadata

# %%
page_metadata = dict()
file_basename = "guideline"

extract_page_size(file_basename, page_metadata)
# Out:
# {0: {'size': [1157, 1571]},
#  1: {'size': [1157, 1571]},
#  2: {'size': [1157, 1571]},
#  3: {'size': [1157, 1571]},
#  4: {'size': [1157, 1571]},
#  5: {'size': [1157, 1571]},
#  6: {'size': [1157, 1571]},
#  7: {'size': [1157, 1571]},
#  8: {'size': [1157, 1571]},
#  9: {'size': [1157, 1571]},
#  10: {'size': [1157, 1571]},
#  11: {'size': [1157, 1571]},
#  12: {'size': [1157, 1571]},
#  13: {'size': [1157, 1571]},
#  14: {'size': [1157, 1571]},
#  15: {'size': [1157, 1571]},
#  16: {'size': [1157, 1571]},
#  17: {'size': [1157, 1571]},
#  18: {'size': [1157, 1571]},
#  19: {'size': [1157, 1571]},
#  20: {'size': [1157, 1571]},
#  21: {'size': [1157, 1571]},
#  22: {'size': [1157, 1571]},
#  23: {'size': [1157, 1571]},
#  24: {'size': [1157, 1571]},
#  25: {'size': [1157, 1571]},
#  26: {'size': [1157, 1571]},
#  27: {'size': [1157, 1571]},
#  28: {'size': [1157, 1571]},
#  29: {'size': [1157, 1571]},
#  30: {'size': [1157, 1571]},
#  31: {'size': [1157, 1571]},
#  32: {'size': [1157, 1571]},
#  33: {'size': [1157, 1571]},
#  34: {'size': [1157, 1571]},
#  35: {'size': [1157, 1571]},
#  36: {'size': [1157, 1571]},
#  37: {'size': [1157, 1571]},
#  38: {'size': [1157, 1571]},
#  39: {'size': [1157, 1571]},
#  40: {'size': [1157, 1571]},
#  41: {'size': [1157, 1571]},
#  42: {'size': [1157, 1571]},
#  43: {'size': [1157, 1571]},
#  44: {'size': [1157, 1571]},
#  45: {'size': [1157, 1571]},
#  46: {'size': [1157, 1571]},
#  47: {'size': [1157, 1571]},
#  48: {'size': [1157, 1571]},
#  49: {'size': [1157, 1571]},
#  50: {'size': [1157, 1571]},
#  51: {'size': [1157, 1571]},
#  52: {'size': [1157, 1571]},
#  53: {'size': [1157, 1571]},
#  54: {'size': [1157, 1571]},
#  55: {'size': [1157, 1571]},
#  56: {'size': [1157, 1571]},
#  57: {'size': [1157, 1571]},
#  58: {'size': [1157, 1571]},
#  59: {'size': [1157, 1571]},
#  60: {'size': [1157, 1571]},
#  61: {'size': [1157, 1571]},
#  62: {'size': [1157, 1571]},
#  63: {'size': [1157, 1571]},
#  64: {'size': [1157, 1571]},
#  65: {'size': [1157, 1571]},
#  66: {'size': [1157, 1571]},
#  67: {'size': [1157, 1571]},
#  68: {'size': [1157, 1571]},
#  69: {'size': [1157, 1571]},
#  70: {'size': [1157, 1571]},
#  71: {'size': [1157, 1571]},
#  72: {'size': [1157, 1571]},
#  73: {'size': [1157, 1571]},
#  74: {'size': [1157, 1571]},
#  75: {'size': [1157, 1571]},
#  76: {'size': [1157, 1571]},
#  77: {'size': [1157, 1571]},
#  78: {'size': [1157, 1571]},
#  79: {'size': [1157, 1571]},
#  80: {'size': [1157, 1571]},
#  81: {'size': [1157, 1571]},
#  82: {'size': [1157, 1571]},
#  83: {'size': [1157, 1571]},
#  84: {'size': [1157, 1571]},
#  85: {'size': [1157, 1571]},
#  86: {'size': [1157, 1571]},
#  87: {'size': [1157, 1571]},
#  88: {'size': [1157, 1571]},
#  89: {'size': [1157, 1571]},
#  90: {'size': [1157, 1571]},
#  91: {'size': [1157, 1571]},
#  92: {'size': [1157, 1571]},
#  93: {'size': [1157, 1571]},
#  94: {'size': [1157, 1571]},
#  95: {'size': [1157, 1571]},
#  96: {'size': [1157, 1571]},
#  97: {'size': [1157, 1571]},
#  98: {'size': [1157, 1571]},
#  99: {'size': [1157, 1571]},
#  100: {'size': [1157, 1571]},
#  101: {'size': [1157, 1571]},
#  102: {'size': [1157, 1571]},
#  103: {'size': [1157, 1571]},
#  104: {'size': [1157, 1571]},
#  105: {'size': [1157, 1571]},
#  106: {'size': [1157, 1571]},
#  107: {'size': [1157, 1571]},
#  108: {'size': [1157, 1571]},
#  109: {'size': [1157, 1571]},
#  110: {'size': [1157, 1571]},
#  111: {'size': [1157, 1571]},
#  112: {'size': [1157, 1571]},
#  113: {'size': [1157, 1571]},
#  114: {'size': [1157, 1571]},
#  115: {'size': [1157, 1571]},
#  116: {'size': [1157, 1571]},
#  117: {'size': [1157, 1571]},
#  118: {'size': [1157, 1571]},
#  119: {'size': [1157, 1571]},
#  120: {'size': [1157, 1571]},
#  121: {'size': [1157, 1571]},
#  122: {'size': [1157, 1571]},
#  123: {'size': [1157, 1571]},
#  124: {'size': [1157, 1571]},
#  125: {'size': [1157, 1571]},
#  126: {'size': [1157, 1571]},
#  127: {'size': [1157, 1571]},
#  128: {'size': [1157, 1571]},
#  129: {'size': [1157, 1571]},
#  130: {'size': [1157, 1571]},
#  131: {'size': [1157, 1571]},
#  132: {'size': [1157, 1571]},
#  133: {'size': [1157, 1571]},
#  134: {'size': [1157, 1571]},
#  135: {'size': [1157, 1571]}}

# %%
def extract_tag_elements_per_page(page_elements):
    splitted_page_elements = dict()

    for key, page_element in page_elements.items():
        figure_elements = []
        table_elements = []
        text_elements = []

        for element in page_element:
            if element["category"] == "figure":
                figure_elements.append(element)
            elif element["category"] == "table":
                table_elements.append(element)
            else:
                text_elements.append(element)

        splitted_page_elements[key] = {
            "figure_elements": figure_elements,
            "table_elements": table_elements,
            "text_elements": text_elements,
            "elements": page_element,
        }

    return splitted_page_elements

# %%
guideline_tag_elements = extract_tag_elements_per_page(guideline_page_elements)

# %%
guideline_tag_elements[70]["figure_elements"][0]
# Out:
# {'bounding_box': [{'x': 145, 'y': 1048},
#   {'x': 1007, 'y': 1048},
#   {'x': 1007, 'y': 1390},
#   {'x': 145, 'y': 1390}],
#  'category': 'figure',
#  'html': '<br><figure><img id=\'10\' style=\'font-size:14px\' alt="② 개별인증 및\n전송요구 완료\n개별인증\n요청 정보제공자 A\nID/PWD\n3 개별인증 순차\n요청 SMS 개별인증 및\n전송요구 완료\n5 개별인증 정보제공자 B 수행\n고객 마이데이터 요청\n서비스\n⑥ 개별인증 및\n전송요구 완료\n정보제공자 C" data-coord="top-left:(145,1048); bottom-right:(1007,1390)" /></figure>',
#  'id': 622,
#  'page': 70,
#  'text': '② 개별인증 및\n전송요구 완료\n개별인증\n요청 정보제공자 A\nID/PWD\n3 개별인증 순차\n요청 SMS 개별인증 및\n전송요구 완료\n5 개별인증 정보제공자 B 수행\n고객 마이데이터 요청\n서비스\n⑥ 개별인증 및\n전송요구 완료\n정보제공자 C'}

# %%
class ImageCropper:
    @staticmethod
    def pdf_to_image(pdf_file, page_num, dpi=300):
        with pymupdf.open(pdf_file) as doc:
            page = doc[page_num].get_pixmap(dpi=dpi)
            target_page_size = [page.width, page.height]
            page_img = Image.frombytes("RGB", target_page_size, page.samples)
        return page_img

    @staticmethod
    def normalize_coordinates(coordinates, output_page_size):
        x_values = [coord["x"] for coord in coordinates]
        y_values = [coord["y"] for coord in coordinates]
        x1, y1, x2, y2 = min(x_values), min(y_values), max(x_values), max(y_values)

        return (
            x1 / output_page_size[0],
            y1 / output_page_size[1],
            x2 / output_page_size[0],
            y2 / output_page_size[1],
        )

    @staticmethod
    def crop_image(img, coordinates, output_file):
        img_width, img_height = img.size
        x1, y1, x2, y2 = [
            int(coord * dim)
            for coord, dim in zip(coordinates, [img_width, img_height] * 2)
        ]
        cropped_img = img.crop((x1, y1, x2, y2))
        cropped_img.save(output_file)

# %%
def crop_image(file_basename):
    cropped_images = dict()
# Out:
# {0: [{'bounding_box': [{'x': 74, 'y': 84},
#     {'x': 1072, 'y': 84},
#     {'x': 1072, 'y': 1484},
#     {'x': 74, 'y': 1484}],
#    'category': 'figure',
#    'html': '<figure><img id=\'0\' style=\'font-size:14px\' alt="금융분야\n마이데이터 기술\n가이드라인\n2022.10.\n금융위원회 금융보안원\nFINANCIAL SECURITY INSTITUTE" data-coord="top-left:(74,84); bottom-right:(1072,1484)" /></figure>',
#    'id': 0,
#    'page': 0,
#    'text': '금융분야\n마이데이터 기술\n가이드라인\n2022.10.\n금융위원회 금융보안원\nFINANCIAL SECURITY INSTITUTE'}],
#  1: [{'bounding_box': [{'x': 291, 'y': 108},
#     {'x': 864, 'y': 108},
#     {'x': 864, 'y': 197},
#     {'x': 291, 'y': 197}],
#    'category': 'heading1',
#    'html': "<h1 id='0' style='font-size:18px'>『금융분야 마이데이터 기술 가이드라인』<br>이용 안내</h1>",
#    'id': 1,
#    'page': 1,
#    'text': '『금융분야 마이데이터 기술 가이드라인』\n이용 안내'},
#   {'bounding_box': [{'x': 160, 'y': 369},
#     {'x': 997, 'y': 369},
#     {'x': 997, 'y': 492},
#     {'x': 160, 'y': 492}],
#    'category': 'paragraph',
#    'html': "<p id='1' data-category='paragraph' style='font-size:14px'>본 가이드라인은 신용정보법 등 관련 법령 및 규정에서 정하지 않는 세부<br>절차 등을 제시하여 안전하고 신뢰 가능한 마이데이터서비스를 제공할 수<br>있도록 마련되었습니다.</p>",
#    'id': 2,
#    'page': 1,
#    'text': '본 가이드라인은 신용정보법 등 관련 법령 및 규정에서 정하지 않는 세부\n절차 등을 제시하여 안전하고 신뢰 가능한 마이데이터서비스를 제공할 수\n있도록 마련되었습니다.'},
#   {'bounding_box': [{'x': 160, 'y': 542},
#     {'x': 995, 'y': 542},
#     {'x': 995, 'y': 622},
#     {'x': 160, 'y': 622}],
#    'category': 'heading1',
#    'html': "<h1 id='2' style='font-size:14px'>관련 법령 및 규정이 본 가이드라인보다 우선하며, 본 가이드라인은 법적인<br>효력이 없음을 알려드립니다.</h1>",
#    'id': 3,
#    'page': 1,
#    'text': '관련 법령 및 규정이 본 가이드라인보다 우선하며, 본 가이드라인은 법적인\n효력이 없음을 알려드립니다.'},
#   {'bounding_box': [{'x': 157, 'y': 671},
#     {'x': 998, 'y': 671},
#     {'x': 998, 'y': 797},
#     {'x': 157, 'y': 797}],
#    'category': 'paragraph',
#    'html': "<p id='3' data-category='paragraph' style='font-size:14px'>본 가이드라인에 기재된 내용 외 이슈사항 및 그에 따른 조치 필요사항은<br>「마이데이터 표준API 규격 관련 이슈사항 및 대응방안」에 기재되어 마이데<br>이터 테스트베드를 통해 수시로 배포 예정입니다.</p>",
#    'id': 4,
#    'page': 1,
#    'text': '본 가이드라인에 기재된 내용 외 이슈사항 및 그에 따른 조치 필요사항은\n「마이데이터 표준API 규격 관련 이슈사항 및 대응방안」에 기재되어 마이데\n이터 테스트베드를 통해 수시로 배포 예정입니다.'},
#   {'bounding_box': [{'x': 160, 'y': 846},
#     {'x': 995, 'y': 846},
#     {'x': 995, 'y': 927},
#     {'x': 160, 'y': 927}],
#    'category': 'paragraph',
#    'html': "<p id='4' data-category='paragraph' style='font-size:14px'>또한 최신성 유지를 위해 마이데이터 지원센터 홈페이지를 통해 최신내용<br>임을 확인할 필요가 있습니다.</p>",
#    'id': 5,
#    'page': 1,
#    'text': '또한 최신성 유지를 위해 마이데이터 지원센터 홈페이지를 통해 최신내용\n임을 확인할 필요가 있습니다.'}],
#  2: [{'bounding_box': [{'x': 712, 'y': 200},
#     {'x': 932, 'y': 200},
#     {'x': 932, 'y': 239},
#     {'x': 712, 'y': 239}],
#    'category': 'heading1',
#    'html': "<h1 id='0' style='font-size:18px'>CONTENTS</h1>",
#    'id': 6,
#    'page': 2,
#    'text': 'CONTENTS'},
#   {'bounding_box': [{'x': 162, 'y': 301},
#     {'x': 976, 'y': 301},
#     {'x': 976, 'y': 1360},
#     {'x': 162, 'y': 1360}],
#    'category': 'index',
#    'html': "<p id='1' data-category='index' style='font-size:14px'>1.1. 목적 2<br>제1장<br>개요 1.2. 적용대상 및 범위 2<br>1.3. 구성 3<br>1.4. 용어 정의 4<br>2.1. 개인신용정보 전송 개요 8<br>제2장<br>가. 개인신용정보 전송요구 8<br>개인신용정보<br>나. 고객 본인인증 11<br>전송<br>다. 개인신용정보 전송 12<br>2.2. 개인신용정보 전송 원칙 14<br>2.3. 개인신용정보 전송 방식 20<br>2.4. 개인신용정보 전송 유형 21<br>2.5. 전송 유형별 전송 절차 및 규격 24<br>가. 고객에 개인신용정보 전송 24<br>나. 마이데이터사업자 외 기관에 개인신용정보 전송 25<br>다. 마이데이터사업자에 개인신용정보 전송 26</p>",
#    'id': 7,
#    'page': 2,
#    'text': '1.1. 목적 2\n제1장\n개요 1.2. 적용대상 및 범위 2\n1.3. 구성 3\n1.4. 용어 정의 4\n2.1. 개인신용정보 전송 개요 8\n제2장\n가. 개인신용정보 전송요구 8\n개인신용정보\n나. 고객 본인인증 11\n전송\n다. 개인신용정보 전송 12\n2.2. 개인신용정보 전송 원칙 14\n2.3. 개인신용정보 전송 방식 20\n2.4. 개인신용정보 전송 유형 21\n2.5. 전송 유형별 전송 절차 및 규격 24\n가. 고객에 개인신용정보 전송 24\n나. 마이데이터사업자 외 기관에 개인신용정보 전송 25\n다. 마이데이터사업자에 개인신용정보 전송 26'}],
#  3: [{'bounding_box': [{'x': 212, 'y': 197},
#     {'x': 550, 'y': 197},
#     {'x': 550, 'y': 224},
#     {'x': 212, 'y': 224}],
#    'category': 'header',
#    'html': "<header id='0' style='font-size:14px'>F in a n C I a C U rity In S tit u te</header>",
#    'id': 8,
#    'page': 3,
#    'text': 'F in a n C I a C U rity In S tit u te'},
#   {'bounding_box': [{'x': 167, 'y': 318},
#     {'x': 1027, 'y': 318},
#     {'x': 1027, 'y': 1339},
#     {'x': 167, 'y': 1339}],
#    'category': 'index',
#    'html': "<p id='1' data-category='index' style='font-size:18px'>3.1. 마이데이터서비스 개요 및 참여자 역할 30<br>제3장<br>가. 마이데이터서비스 주요절차 30<br>마이데이터<br>나. 마이데이터서비스 주요 참여자 및 역할 31<br>서비스<br>다. 마이데이터서비스 주요 제공 기능 및 참여자 역할 36<br>3.2. 마이데이터서비스 등록 준비 44<br>3.3. 마이데이터 개인신용정보 전송 절차 44<br>3.4. 마이데이터 개인신용정보 전송 내역 관리 47<br>가. 마이데이터 개인신용정보 전송요구 내역 조회 47<br>나. 마이데이터 개인신용정보 전송요구 내역 변경 48<br>다. 마이데이터 개인신용정보 전송요구 내역 철회 49<br>라. 마이데이터 개인신용정보 전송요구 기간 연장 51<br>마. 마이데이터 개인신용정보 전송 내역 관리 53<br>4.1. 마이데이터 본인인증 개요 56<br>제4장<br>가. 본인인증 기본 원칙 56<br>마이데이터 나. 본인인증 수단 60<br>본인인증 다. 본인인증 절차 61<br>4.2. 개별인증 63<br>4.3. 통합인증 65<br>4.4. 중계기관을 통한 본인인증 69</p>",
#    'id': 9,
#    'page': 3,
#    'text': '3.1. 마이데이터서비스 개요 및 참여자 역할 30\n제3장\n가. 마이데이터서비스 주요절차 30\n마이데이터\n나. 마이데이터서비스 주요 참여자 및 역할 31\n서비스\n다. 마이데이터서비스 주요 제공 기능 및 참여자 역할 36\n3.2. 마이데이터서비스 등록 준비 44\n3.3. 마이데이터 개인신용정보 전송 절차 44\n3.4. 마이데이터 개인신용정보 전송 내역 관리 47\n가. 마이데이터 개인신용정보 전송요구 내역 조회 47\n나. 마이데이터 개인신용정보 전송요구 내역 변경 48\n다. 마이데이터 개인신용정보 전송요구 내역 철회 49\n라. 마이데이터 개인신용정보 전송요구 기간 연장 51\n마. 마이데이터 개인신용정보 전송 내역 관리 53\n4.1. 마이데이터 본인인증 개요 56\n제4장\n가. 본인인증 기본 원칙 56\n마이데이터 나. 본인인증 수단 60\n본인인증 다. 본인인증 절차 61\n4.2. 개별인증 63\n4.3. 통합인증 65\n4.4. 중계기관을 통한 본인인증 69'}],
#  4: [{'bounding_box': [{'x': 177, 'y': 419},
#     {'x': 300, 'y': 419},
#     {'x': 300, 'y': 542},
#     {'x': 177, 'y': 542}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:16px'>제5장<br>마이데이터<br>보안</p>",
#    'id': 10,
#    'page': 4,
#    'text': '제5장\n마이데이터\n보안'},
#   {'bounding_box': [{'x': 714, 'y': 201},
#     {'x': 933, 'y': 201},
#     {'x': 933, 'y': 239},
#     {'x': 714, 'y': 239}],
#    'category': 'heading1',
#    'html': "<br><h1 id='1' style='font-size:20px'>CONTENTS</h1>",
#    'id': 11,
#    'page': 4,
#    'text': 'CONTENTS'},
#   {'bounding_box': [{'x': 369, 'y': 404},
#     {'x': 977, 'y': 404},
#     {'x': 977, 'y': 1296},
#     {'x': 369, 'y': 1296}],
#    'category': 'index',
#    'html': "<p id='2' data-category='index' style='font-size:14px'>5.1. 마이데이터 보안 개요 71<br>가. 목 적 71<br>나. 관련법규 및 규정 71<br>5.2. 관리적 보안사항 74<br>가 신용정보관리 보호인 74<br>나. 개인신용정보 보호 교육 76<br>다. 개인신용정보 관리 77<br>라. 개인신용정보처리 시스템 접근 관리 80<br>마. 직무분리 82<br>바. API 시스템 관리 82<br>사. 이용자 보호 83<br>아. 재해 · 재난 대응 대비 86<br>5.3. 물리적 보안사항 87<br>가. 접근통제 87<br>나. 물리적 보안 88<br>5.4. 기술적 보안사항 88<br>가. 비밀번호 관리 88<br>나. 암호 통제 89<br>다. 시스템 보안 92<br>라. 개발 보안 93<br>마. 출력 · 복사 시 보호조치 94</p>",
#    'id': 12,
#    'page': 4,
#    'text': '5.1. 마이데이터 보안 개요 71\n가. 목 적 71\n나. 관련법규 및 규정 71\n5.2. 관리적 보안사항 74\n가 신용정보관리 보호인 74\n나. 개인신용정보 보호 교육 76\n다. 개인신용정보 관리 77\n라. 개인신용정보처리 시스템 접근 관리 80\n마. 직무분리 82\n바. API 시스템 관리 82\n사. 이용자 보호 83\n아. 재해 · 재난 대응 대비 86\n5.3. 물리적 보안사항 87\n가. 접근통제 87\n나. 물리적 보안 88\n5.4. 기술적 보안사항 88\n가. 비밀번호 관리 88\n나. 암호 통제 89\n다. 시스템 보안 92\n라. 개발 보안 93\n마. 출력 · 복사 시 보호조치 94'}],
#  5: [{'bounding_box': [{'x': 212, 'y': 197},
#     {'x': 550, 'y': 197},
#     {'x': 550, 'y': 224},
#     {'x': 212, 'y': 224}],
#    'category': 'header',
#    'html': "<header id='0' style='font-size:14px'>F in a n C la I S e C u rity In S titu te</header>",
#    'id': 13,
#    'page': 5,
#    'text': 'F in a n C la I S e C u rity In S titu te'},
#   {'bounding_box': [{'x': 130, 'y': 230},
#     {'x': 1043, 'y': 230},
#     {'x': 1043, 'y': 1471},
#     {'x': 130, 'y': 1471}],
#    'category': 'figure',
#    'html': '<br><figure><img id=\'1\' style=\'font-size:18px\' alt="1. 개인신용정보 전송 97\n제6장\n2. 마이데이터서비스 101\nQ&A\n3. API 105\n4. 본인인증 108\n5. 정보보호시설 . 보안 112\n참고 1. 정보제공자· 정보수신자 범위 118\n제7장\n가. 정보제공자 범위 118\n나. 정보수신자 범위 119\n참고\n참고 2. 본인신용정보관리업자 허가요건 및 절차 120\n참고 3. 주요 인증 규격(가이드라인)의 인증 수준 요구 현황 122\n참고 4. 비대면 실명확인 방식 124\n참고 5. 마이데이터 정보제공자용 접근토큰 관리 자체점검표 126" data-coord="top-left:(130,230); bottom-right:(1043,1471)" /></figure>',
#    'id': 14,
#    'page': 5,
#    'text': '1. 개인신용정보 전송 97\n제6장\n2. 마이데이터서비스 101\nQ&A\n3. API 105\n4. 본인인증 108\n5. 정보보호시설 . 보안 112\n참고 1. 정보제공자· 정보수신자 범위 118\n제7장\n가. 정보제공자 범위 118\n나. 정보수신자 범위 119\n참고\n참고 2. 본인신용정보관리업자 허가요건 및 절차 120\n참고 3. 주요 인증 규격(가이드라인)의 인증 수준 요구 현황 122\n참고 4. 비대면 실명확인 방식 124\n참고 5. 마이데이터 정보제공자용 접근토큰 관리 자체점검표 126'}],
#  6: [{'bounding_box': [{'x': 502, 'y': 111},
#     {'x': 653, 'y': 111},
#     {'x': 653, 'y': 156},
#     {'x': 502, 'y': 156}],
#    'category': 'heading1',
#    'html': "<h1 id='0' style='font-size:18px'>개정 이력</h1>",
#    'id': 15,
#    'page': 6,
#    'text': '개정 이력'},
#   {'bounding_box': [{'x': 163, 'y': 282},
#     {'x': 1002, 'y': 282},
#     {'x': 1002, 'y': 1383},
#     {'x': 163, 'y': 1383}],
#    'category': 'table',
#    'html': "<table id='1' style='font-size:14px'><tr><td>버전</td><td>개정일자</td><td>내 용</td><td>작성자</td></tr><tr><td>1.0</td><td>2021.2.23</td><td>금융분야 마이데이터 기술 가이드라인 제정</td><td>금융보안원</td></tr><tr><td>1.0</td><td>2021.3.23</td><td>오탈자 및 내용 오류 수정 - (10p) 전송을 요구하는 개인신용정보 : 비고 '전송받는 기간' 삭제 - (17p) 정기적 전송 : 1주의 기준 시점 '일요일→토요일(7일)'로 변경 - (19p) 개인신용정보 삭제 : 오타 수정 (정보제공자를 정보수신자로 수정) - (26p) 예시표 수정(개인신용정보를 제공 받는 자 x→o 로 수정) - (43p) 서비스 등록 준비 TLS 관련 내용 삭제 - (50p) 개인신용정보 전송요구 철회 절차 수정(본인인증 삭제)</td><td>금융보안원</td></tr><tr><td>1.0</td><td>2021.4.19</td><td>일부 내용 추가 및 수정 - (12p) 전송지연시 마이데이터사업자의 고객 고지 의무 추가 - (41p, 42p) 개인신용정보 전송 내역 예시 추가 - (46p, 49p, 53p) 인증방식에 따라 일부 절차가 다를 수 있음 안내 추가 - (67p) 그림 수정</td><td>금융보안원</td></tr><tr><td>1.0</td><td>2021.5. 21</td><td>- (12p) 지연 전송 재개 안내 - (41p, 42p) 개인신용정보 전송 내역 보관 기간 등 내용 추가 - (78p) 개인신용정보 삭제 내용 수정 - (99p) Q&A 추가 - (103p, 109p) Q&A 내용 수정(테스트 베드 관련)</td><td>금융보안원</td></tr></table>",
#    'id': 16,
#    'page': 6,
#    'text': "버전 개정일자 내 용 작성자\n 1.0 2021.2.23 금융분야 마이데이터 기술 가이드라인 제정 금융보안원\n 1.0 2021.3.23 오탈자 및 내용 오류 수정 - (10p) 전송을 요구하는 개인신용정보 : 비고 '전송받는 기간' 삭제 - (17p) 정기적 전송 : 1주의 기준 시점 '일요일→토요일(7일)'로 변경 - (19p) 개인신용정보 삭제 : 오타 수정 (정보제공자를 정보수신자로 수정) - (26p) 예시표 수정(개인신용정보를 제공 받는 자 x→o 로 수정) - (43p) 서비스 등록 준비 TLS 관련 내용 삭제 - (50p) 개인신용정보 전송요구 철회 절차 수정(본인인증 삭제) 금융보안원\n 1.0 2021.4.19 일부 내용 추가 및 수정 - (12p) 전송지연시 마이데이터사업자의 고객 고지 의무 추가 - (41p, 42p) 개인신용정보 전송 내역 예시 추가 - (46p, 49p, 53p) 인증방식에 따라 일부 절차가 다를 수 있음 안내 추가 - (67p) 그림 수정 금융보안원\n 1.0 2021.5. 21 - (12p) 지연 전송 재개 안내 - (41p, 42p) 개인신용정보 전송 내역 보관 기간 등 내용 추가 - (78p) 개인신용정보 삭제 내용 수정 - (99p) Q&A 추가 - (103p, 109p) Q&A 내용 수정(테스트 베드 관련) 금융보안원"}],
#  7: [{'bounding_box': [{'x': 502, 'y': 111},
#     {'x': 652, 'y': 111},
#     {'x': 652, 'y': 155},
#     {'x': 502, 'y': 155}],
#    'category': 'heading1',
#    'html': "<h1 id='0' style='font-size:18px'>개정 이력</h1>",
#    'id': 17,
#    'page': 7,
#    'text': '개정 이력'},
#   {'bounding_box': [{'x': 155, 'y': 232},
#     {'x': 1018, 'y': 232},
#     {'x': 1018, 'y': 1355},
#     {'x': 155, 'y': 1355}],
#    'category': 'table',
#    'html': "<table id='1' style='font-size:14px'><tr><td>버전</td><td>개정일자</td><td>내 용</td><td>작성자</td></tr><tr><td>1.0</td><td>2021.7.29.</td><td>- (5,6p) 용어 수정 - (10p) 알고하는 동의 반영 - (13p) 지연고지 면제(정기적 전송시) - (17p) API 기준 조회 기간 추가 - (18p) 정기적 전송 주기 변경 - (23p) 스크레이핑 금지 기간 변경 - (32p) 통합인증기관 요건 추가 - (41p) 전송내역 보관기간 변경 - (50p,51p) 개인신용정보 삭제 및 회원 탈퇴 수정 - (58p) 인증수단 제공 방식 변경 - (60p) 인증수단 예시 수정 - (65P) 통합인증수단 제공 방식 변경 - (66p) 통합인증 절차 추가 - (68p) 정보제공자 선택 화면구성 추가 - (97p~115p) Q&A 수정 ·추가 - (124p) 비대면실명확인 방식 수정</td><td>금융보안원</td></tr><tr><td>1.0</td><td>2021.11.10.</td><td>- (15p) 비밀, 보안 계좌 전송 수정 - (26p) 개인신용정보 전송 방식 수정 - (49p) 철회 절차 오류 수정 - (58p) 인증방식 제공 기준 수정 - (69p) 중계기관 본인인증 방식 수정 - (79p) 개인신용정보 삭제 수정 - (83p) 클라우드 이용 관련 문구 수정</td><td>금융보안원</td></tr><tr><td>1.0</td><td>2022.10</td><td>- 「금융분야 마이데이터 기술 가이드라 인 이용안내」 수정 - (10p) 전송을 요구하는 목적에 '데이터 분석 서비스의 이용' 추가 - (36,40p) 접근토큰 리프레시토큰 발급· 관리 의무 추가 - (36,40p) 접근토큰 · 리프레시토큰 중복 발급 여부 확인 의무 추가 - (52p) 용어 수정 - (55p) 내용 오류 삭제</td><td>금융보안원</td></tr></table>",
#    'id': 18,
#    'page': 7,
#    'text': "버전 개정일자 내 용 작성자\n 1.0 2021.7.29. - (5,6p) 용어 수정 - (10p) 알고하는 동의 반영 - (13p) 지연고지 면제(정기적 전송시) - (17p) API 기준 조회 기간 추가 - (18p) 정기적 전송 주기 변경 - (23p) 스크레이핑 금지 기간 변경 - (32p) 통합인증기관 요건 추가 - (41p) 전송내역 보관기간 변경 - (50p,51p) 개인신용정보 삭제 및 회원 탈퇴 수정 - (58p) 인증수단 제공 방식 변경 - (60p) 인증수단 예시 수정 - (65P) 통합인증수단 제공 방식 변경 - (66p) 통합인증 절차 추가 - (68p) 정보제공자 선택 화면구성 추가 - (97p~115p) Q&A 수정 ·추가 - (124p) 비대면실명확인 방식 수정 금융보안원\n 1.0 2021.11.10. - (15p) 비밀, 보안 계좌 전송 수정 - (26p) 개인신용정보 전송 방식 수정 - (49p) 철회 절차 오류 수정 - (58p) 인증방식 제공 기준 수정 - (69p) 중계기관 본인인증 방식 수정 - (79p) 개인신용정보 삭제 수정 - (83p) 클라우드 이용 관련 문구 수정 금융보안원\n 1.0 2022.10 - 「금융분야 마이데이터 기술 가이드라 인 이용안내」 수정 - (10p) 전송을 요구하는 목적에 '데이터 분석 서비스의 이용' 추가 - (36,40p) 접근토큰 리프레시토큰 발급· 관리 의무 추가 - (36,40p) 접근토큰 · 리프레시토큰 중복 발급 여부 확인 의무 추가 - (52p) 용어 수정 - (55p) 내용 오류 삭제 금융보안원"}],
#  8: [{'bounding_box': [{'x': 502, 'y': 111},
#     {'x': 653, 'y': 111},
#     {'x': 653, 'y': 155},
#     {'x': 502, 'y': 155}],
#    'category': 'heading1',
#    'html': "<h1 id='0' style='font-size:18px'>개정 이력</h1>",
#    'id': 19,
#    'page': 8,
#    'text': '개정 이력'},
#   {'bounding_box': [{'x': 137, 'y': 234},
#     {'x': 985, 'y': 234},
#     {'x': 985, 'y': 588},
#     {'x': 137, 'y': 588}],
#    'category': 'table',
#    'html': "<table id='1' style='font-size:14px'><tr><td>버전</td><td>개정일자</td><td>내 용</td><td>작성자</td></tr><tr><td></td><td></td><td>- (66p) 보유자산·상품 확인 단계 생략 안내 추가 - (83p) 중복토큰 관리 및 확인 시 처리 절차 추가 - (106p) Q&A 추가 - (126p) 참고5. 정보제공자용 접근토큰 관리 자체점검표 추가</td><td></td></tr><tr><td>1.0</td><td>2022.10. (221115 수정)</td><td>- (33,44,58,103,108p) 개별인증 제공 필수를 선택으로 변경</td><td>금융보안원</td></tr></table>",
#    'id': 20,
#    'page': 8,
#    'text': '버전 개정일자 내 용 작성자\n   - (66p) 보유자산·상품 확인 단계 생략 안내 추가 - (83p) 중복토큰 관리 및 확인 시 처리 절차 추가 - (106p) Q&A 추가 - (126p) 참고5. 정보제공자용 접근토큰 관리 자체점검표 추가 \n 1.0 2022.10. (221115 수정) - (33,44,58,103,108p) 개별인증 제공 필수를 선택으로 변경 금융보안원'}],
#  9: [{'bounding_box': [{'x': 218, 'y': 604},
#     {'x': 321, 'y': 604},
#     {'x': 321, 'y': 656},
#     {'x': 218, 'y': 656}],
#    'category': 'heading1',
#    'html': "<h1 id='0' style='font-size:18px'>개요</h1>",
#    'id': 21,
#    'page': 9,
#    'text': '개요'},
#   {'bounding_box': [{'x': 937, 'y': 566},
#     {'x': 1026, 'y': 566},
#     {'x': 1026, 'y': 601},
#     {'x': 937, 'y': 601}],
#    'category': 'paragraph',
#    'html': "<br><p id='1' data-category='paragraph' style='font-size:16px'>PART.</p>",
#    'id': 22,
#    'page': 9,
#    'text': 'PART.'},
#   {'bounding_box': [{'x': 849, 'y': 622},
#     {'x': 1024, 'y': 622},
#     {'x': 1024, 'y': 766},
#     {'x': 849, 'y': 766}],
#    'category': 'heading1',
#    'html': "<br><h1 id='2' style='font-size:20px'>O 1</h1>",
#    'id': 23,
#    'page': 9,
#    'text': 'O 1'},
#   {'bounding_box': [{'x': 223, 'y': 762},
#     {'x': 751, 'y': 762},
#     {'x': 751, 'y': 993},
#     {'x': 223, 'y': 993}],
#    'category': 'list',
#    'html': "<br><p id='3' data-category='list' style='font-size:16px'>1.1. 목적 2<br>1.2. 적용대상 및 범위 2<br>1.3. 구성 3<br>1.4. 용어 정의 4</p>",
#    'id': 24,
#    'page': 9,
#    'text': '1.1. 목적 2\n1.2. 적용대상 및 범위 2\n1.3. 구성 3\n1.4. 용어 정의 4'},
#   {'bounding_box': [{'x': 565, 'y': 1389},
#     {'x': 959, 'y': 1389},
#     {'x': 959, 'y': 1422},
#     {'x': 565, 'y': 1422}],
#    'category': 'paragraph',
#    'html': "<p id='4' data-category='paragraph' style='font-size:14px'>금융분야 마이데이터 기술 가이드라인</p>",
#    'id': 25,
#    'page': 9,
#    'text': '금융분야 마이데이터 기술 가이드라인'}],
#  10: [{'bounding_box': [{'x': 129, 'y': 142},
#     {'x': 401, 'y': 142},
#     {'x': 401, 'y': 169},
#     {'x': 129, 'y': 169}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:14px'>금융분야 마이데이터 기술 가이드라인</p>",
#    'id': 26,
#    'page': 10,
#    'text': '금융분야 마이데이터 기술 가이드라인'},
#   {'bounding_box': [{'x': 174, 'y': 251},
#     {'x': 200, 'y': 251},
#     {'x': 200, 'y': 298},
#     {'x': 174, 'y': 298}],
#    'category': 'paragraph',
#    'html': "<p id='1' data-category='paragraph' style='font-size:22px'>1</p>",
#    'id': 27,
#    'page': 10,
#    'text': '1'},
#   {'bounding_box': [{'x': 248, 'y': 257},
#     {'x': 315, 'y': 257},
#     {'x': 315, 'y': 292},
#     {'x': 248, 'y': 292}],
#    'category': 'heading1',
#    'html': "<br><h1 id='2' style='font-size:18px'>개요</h1>",
#    'id': 28,
#    'page': 10,
#    'text': '개요'},
#   {'bounding_box': [{'x': 146, 'y': 392},
#     {'x': 1010, 'y': 392},
#     {'x': 1010, 'y': 462},
#     {'x': 146, 'y': 462}],
#    'category': 'paragraph',
#    'html': "<p id='3' data-category='paragraph' style='font-size:16px'>본 장은 가이드라인의 목적, 적용대상 및 범위, 구성, 용어정의 등 서비스 제공에 있어서 기본적으로<br>확인해야 할 내용을 다룬다.</p>",
#    'id': 29,
#    'page': 10,
#    'text': '본 장은 가이드라인의 목적, 적용대상 및 범위, 구성, 용어정의 등 서비스 제공에 있어서 기본적으로\n확인해야 할 내용을 다룬다.'},
#   {'bounding_box': [{'x': 134, 'y': 574},
#     {'x': 269, 'y': 574},
#     {'x': 269, 'y': 617},
#     {'x': 134, 'y': 617}],
#    'category': 'heading1',
#    'html': "<h1 id='4' style='font-size:20px'>1.1. 목적</h1>",
#    'id': 30,
#    'page': 10,
#    'text': '1.1. 목적'},
#   {'bounding_box': [{'x': 127, 'y': 661},
#     {'x': 1026, 'y': 661},
#     {'x': 1026, 'y': 786},
#     {'x': 127, 'y': 786}],
#    'category': 'paragraph',
#    'html': "<p id='5' data-category='paragraph' style='font-size:16px'>신용정보법에 따른 고객의 개인신용정보 전송요구 및 금융분야 마이데이터서비스<br>제공과 관련된 세부절차, 기준 등을 제시하여, 관련 이해관계자들이 안전하고 편리한<br>개인신용정보 전송 및 마이데이터서비스를 제공하도록 하는 데 있다.</p>",
#    'id': 31,
#    'page': 10,
#    'text': '신용정보법에 따른 고객의 개인신용정보 전송요구 및 금융분야 마이데이터서비스\n제공과 관련된 세부절차, 기준 등을 제시하여, 관련 이해관계자들이 안전하고 편리한\n개인신용정보 전송 및 마이데이터서비스를 제공하도록 하는 데 있다.'},
#   {'bounding_box': [{'x': 134, 'y': 878},
#     {'x': 434, 'y': 878},
#     {'x': 434, 'y': 921},
#     {'x': 134, 'y': 921}],
#    'category': 'heading1',
#    'html': "<h1 id='6' style='font-size:20px'>1.2. 적용대상 및 범위</h1>",
#    'id': 32,
#    'page': 10,
#    'text': '1.2. 적용대상 및 범위'},
#   {'bounding_box': [{'x': 128, 'y': 965},
#     {'x': 1027, 'y': 965},
#     {'x': 1027, 'y': 1175},
#     {'x': 128, 'y': 1175}],
#    'category': 'list',
#    'html': "<p id='7' data-category='list' style='font-size:16px'>。 (대상) 신용정보법에 따라 개인신용정보를 보유하여 정보주체(이하 고객)의 요구에<br>따라 개인신용정보를 전송하는 신용정보제공·이용자등(이하 정보제공자)과 고객의<br>전송요구에 의해 개인신용정보를 전송받는 자(이하 정보수신자), 수집한 개인신용정보를<br>이용하여 고객에게 개인신용정보 통합조회서비스 등을 제공하는 마이데이터사업자등을<br>주요 대상으로 한다.</p>",
#    'id': 33,
#    'page': 10,
#    'text': '。 (대상) 신용정보법에 따라 개인신용정보를 보유하여 정보주체(이하 고객)의 요구에\n따라 개인신용정보를 전송하는 신용정보제공·이용자등(이하 정보제공자)과 고객의\n전송요구에 의해 개인신용정보를 전송받는 자(이하 정보수신자), 수집한 개인신용정보를\n이용하여 고객에게 개인신용정보 통합조회서비스 등을 제공하는 마이데이터사업자등을\n주요 대상으로 한다.'},
#   {'bounding_box': [{'x': 129, 'y': 1226},
#     {'x': 1026, 'y': 1226},
#     {'x': 1026, 'y': 1350},
#     {'x': 129, 'y': 1350}],
#    'category': 'paragraph',
#    'html': "<p id='8' data-category='paragraph' style='font-size:16px'>。 (범위) 신용정보법 상 마이데이터서비스와 관련한 사전준비사항, 전송요구, 전송요구에<br>따른 데이터 전송 과정에서 개인신용정보를 안전하게 전송하기 위한 방법 ·절차, 인증<br>및 보안 사항 등을 다룬다.</p>",
#    'id': 34,
#    'page': 10,
#    'text': '。 (범위) 신용정보법 상 마이데이터서비스와 관련한 사전준비사항, 전송요구, 전송요구에\n따른 데이터 전송 과정에서 개인신용정보를 안전하게 전송하기 위한 방법 ·절차, 인증\n및 보안 사항 등을 다룬다.'},
#   {'bounding_box': [{'x': 130, 'y': 1479},
#     {'x': 230, 'y': 1479},
#     {'x': 230, 'y': 1506},
#     {'x': 130, 'y': 1506}],
#    'category': 'footer',
#    'html': "<footer id='9' style='font-size:14px'>2 금융보안원</footer>",
#    'id': 35,
#    'page': 10,
#    'text': '2 금융보안원'}],
#  11: [{'bounding_box': [{'x': 958, 'y': 143},
#     {'x': 1025, 'y': 143},
#     {'x': 1025, 'y': 169},
#     {'x': 958, 'y': 169}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:14px'>1장. 개요</p>",
#    'id': 36,
#    'page': 11,
#    'text': '1장. 개요'},
#   {'bounding_box': [{'x': 166, 'y': 236},
#     {'x': 218, 'y': 236},
#     {'x': 218, 'y': 266},
#     {'x': 166, 'y': 266}],
#    'category': 'heading1',
#    'html': "<h1 id='1' style='font-size:18px'>참고</h1>",
#    'id': 37,
#    'page': 11,
#    'text': '참고'},
#   {'bounding_box': [{'x': 177, 'y': 297},
#     {'x': 998, 'y': 297},
#     {'x': 998, 'y': 365},
#     {'x': 177, 'y': 365}],
#    'category': 'paragraph',
#    'html': "<p id='2' data-category='paragraph' style='font-size:16px'>본 가이드라인의 내용은 전송대상 간 원활한 개인신용정보 전송, 고객의 이용편의를 해치지 않는<br>경우, 일부 처리 순서 등을 변경하여 적용할 수 있다.</p>",
#    'id': 38,
#    'page': 11,
#    'text': '본 가이드라인의 내용은 전송대상 간 원활한 개인신용정보 전송, 고객의 이용편의를 해치지 않는\n경우, 일부 처리 순서 등을 변경하여 적용할 수 있다.'},
#   {'bounding_box': [{'x': 133, 'y': 481},
#     {'x': 268, 'y': 481},
#     {'x': 268, 'y': 525},
#     {'x': 133, 'y': 525}],
#    'category': 'heading1',
#    'html': "<h1 id='3' style='font-size:22px'>1.3. 구성</h1>",
#    'id': 39,
#    'page': 11,
#    'text': '1.3. 구성'},
#   {'bounding_box': [{'x': 128, 'y': 568},
#     {'x': 844, 'y': 568},
#     {'x': 844, 'y': 606},
#     {'x': 128, 'y': 606}],
#    'category': 'paragraph',
#    'html': "<p id='4' data-category='paragraph' style='font-size:20px'>본 가이드라인은 총 5장으로 구성되며 각 장의 내용은 아래와 같다.</p>",
#    'id': 40,
#    'page': 11,
#    'text': '본 가이드라인은 총 5장으로 구성되며 각 장의 내용은 아래와 같다.'},
#   {'bounding_box': [{'x': 166, 'y': 656},
#     {'x': 852, 'y': 656},
#     {'x': 852, 'y': 693},
#     {'x': 166, 'y': 693}],
#    'category': 'list',
#    'html': "<p id='5' data-category='list' style='font-size:20px'>- (1장. 개요) 가이드라인의 목적과 구성, 용어 정의 등을 설명한다.</p>",
#    'id': 41,
#    'page': 11,
#    'text': '- (1장. 개요) 가이드라인의 목적과 구성, 용어 정의 등을 설명한다.'},
#   {'bounding_box': [{'x': 165, 'y': 742},
#     {'x': 1026, 'y': 742},
#     {'x': 1026, 'y': 824},
#     {'x': 165, 'y': 824}],
#    'category': 'list',
#    'html': "<p id='6' data-category='list' style='font-size:20px'>- (2장. 개인신용정보 전송) 고객이 정보제공자에게 개인신용정보 전송요구권을 행사<br>하는데 있어서 필요한 기본원칙, 전송방식과 전송유형 등을 설명한다.</p>",
#    'id': 42,
#    'page': 11,
#    'text': '- (2장. 개인신용정보 전송) 고객이 정보제공자에게 개인신용정보 전송요구권을 행사\n하는데 있어서 필요한 기본원칙, 전송방식과 전송유형 등을 설명한다.'},
#   {'bounding_box': [{'x': 165, 'y': 872},
#     {'x': 1027, 'y': 872},
#     {'x': 1027, 'y': 954},
#     {'x': 165, 'y': 954}],
#    'category': 'list',
#    'html': "<p id='7' data-category='list' style='font-size:20px'>- (3장. 마이데이터서비스) 신용정보법 상 마이데이터서비스(통합조회 서비스)와<br>관련된 참여자의 역할, 준비 필요사항, 참여자 간 세부 전송절차등을 설명한다.</p>",
#    'id': 43,
#    'page': 11,
#    'text': '- (3장. 마이데이터서비스) 신용정보법 상 마이데이터서비스(통합조회 서비스)와\n관련된 참여자의 역할, 준비 필요사항, 참여자 간 세부 전송절차등을 설명한다.'},
#   {'bounding_box': [{'x': 164, 'y': 1002},
#     {'x': 1027, 'y': 1002},
#     {'x': 1027, 'y': 1123},
#     {'x': 164, 'y': 1123}],
#    'category': 'list',
#    'html': "<p id='8' data-category='list' style='font-size:20px'>- (4장. 마이데이터 본인인증) 신용정보법 상 마이데이터서비스 제공과 관련하여<br>고객의 개인신용정보 전송 요구 시 수행되는 고객 본인인증 요건 및 절차 등을 설명<br>한다.</p>",
#    'id': 44,
#    'page': 11,
#    'text': '- (4장. 마이데이터 본인인증) 신용정보법 상 마이데이터서비스 제공과 관련하여\n고객의 개인신용정보 전송 요구 시 수행되는 고객 본인인증 요건 및 절차 등을 설명\n한다.'},
#   {'bounding_box': [{'x': 165, 'y': 1175},
#     {'x': 1024, 'y': 1175},
#     {'x': 1024, 'y': 1256},
#     {'x': 165, 'y': 1256}],
#    'category': 'paragraph',
#    'html': "<p id='9' data-category='paragraph' style='font-size:20px'>- (5장. 마이데이터 보안) 신용정보법 상 마이데이터서비스와 관련하여 안전한 개인<br>신용정보 전송을 위해 준수해야 할 보안관련사항을 설명한다.</p>",
#    'id': 45,
#    'page': 11,
#    'text': '- (5장. 마이데이터 보안) 신용정보법 상 마이데이터서비스와 관련하여 안전한 개인\n신용정보 전송을 위해 준수해야 할 보안관련사항을 설명한다.'},
#   {'bounding_box': [{'x': 811, 'y': 1481},
#     {'x': 1026, 'y': 1481},
#     {'x': 1026, 'y': 1506},
#     {'x': 811, 'y': 1506}],
#    'category': 'footer',
#    'html': "<footer id='10' style='font-size:14px'>Financial Security Institute 3</footer>",
#    'id': 46,
#    'page': 11,
#    'text': 'Financial Security Institute 3'}],
#  12: [{'bounding_box': [{'x': 128, 'y': 142},
#     {'x': 401, 'y': 142},
#     {'x': 401, 'y': 169},
#     {'x': 128, 'y': 169}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:14px'>금융분야 마이데이터 기술 가이드라인</p>",
#    'id': 47,
#    'page': 12,
#    'text': '금융분야 마이데이터 기술 가이드라인'},
#   {'bounding_box': [{'x': 135, 'y': 228},
#     {'x': 336, 'y': 228},
#     {'x': 336, 'y': 270},
#     {'x': 135, 'y': 270}],
#    'category': 'heading1',
#    'html': "<h1 id='1' style='font-size:22px'>1.4. 용어 정의</h1>",
#    'id': 48,
#    'page': 12,
#    'text': '1.4. 용어 정의'},
#   {'bounding_box': [{'x': 127, 'y': 314},
#     {'x': 1024, 'y': 314},
#     {'x': 1024, 'y': 394},
#     {'x': 127, 'y': 394}],
#    'category': 'paragraph',
#    'html': "<p id='2' data-category='paragraph' style='font-size:20px'>본 가이드라인에서 사용하는 용어는 아래와 같으며 그 외 용어는 신용정보법 및 관련<br>법규의 용어를 따른다.</p>",
#    'id': 49,
#    'page': 12,
#    'text': '본 가이드라인에서 사용하는 용어는 아래와 같으며 그 외 용어는 신용정보법 및 관련\n법규의 용어를 따른다.'},
#   {'bounding_box': [{'x': 163, 'y': 445},
#     {'x': 1027, 'y': 445},
#     {'x': 1027, 'y': 521},
#     {'x': 163, 'y': 521}],
#    'category': 'list',
#    'html': "<p id='3' data-category='list' style='font-size:16px'>※ 가급적 신용정보법 및 관련 법규의 용어를 따르도록 하였으나, 일부 용어는 보다 쉬운<br>이해를 위해 별도로 정의하였음(고객, 정보제공자, 정보수신자, 마이데이터사업자 등)</p>",
#    'id': 50,
#    'page': 12,
#    'text': '※ 가급적 신용정보법 및 관련 법규의 용어를 따르도록 하였으나, 일부 용어는 보다 쉬운\n이해를 위해 별도로 정의하였음(고객, 정보제공자, 정보수신자, 마이데이터사업자 등)'},
#   {'bounding_box': [{'x': 165, 'y': 568},
#     {'x': 1025, 'y': 568},
#     {'x': 1025, 'y': 648},
#     {'x': 165, 'y': 648}],
#    'category': 'list',
#    'html': "<p id='4' data-category='list' style='font-size:18px'>- (개인신용정보) 금융거래 등 상거래에서 개인인 정보주체의 신용, 거래내용, 거래능력<br>등을 판단할 수 있는 정보</p>",
#    'id': 51,
#    'page': 12,
#    'text': '- (개인신용정보) 금융거래 등 상거래에서 개인인 정보주체의 신용, 거래내용, 거래능력\n등을 판단할 수 있는 정보'},
#   {'bounding_box': [{'x': 163, 'y': 698},
#     {'x': 1024, 'y': 698},
#     {'x': 1024, 'y': 779},
#     {'x': 163, 'y': 779}],
#    'category': 'list',
#    'html': "<p id='5' data-category='list' style='font-size:18px'>- (고객) 처리된 개인신용정보로 알아볼 수 있는 정보주체로 개인신용정보 전송 요구권을<br>행사하는 자(신용정보법 상 개인인 신용정보주체)</p>",
#    'id': 52,
#    'page': 12,
#    'text': '- (고객) 처리된 개인신용정보로 알아볼 수 있는 정보주체로 개인신용정보 전송 요구권을\n행사하는 자(신용정보법 상 개인인 신용정보주체)'},
#   {'bounding_box': [{'x': 164, 'y': 828},
#     {'x': 1025, 'y': 828},
#     {'x': 1025, 'y': 910},
#     {'x': 164, 'y': 910}],
#    'category': 'list',
#    'html': "<p id='6' data-category='list' style='font-size:18px'>- (정보제공자) 고객의 개인신용정보 전송요구에 따라 보유하고 있는 고객의 개인신용<br>정보를 정보수신자에게 전송하는 자(신용정보법 상 신용정보제공·이용자)</p>",
#    'id': 53,
#    'page': 12,
#    'text': '- (정보제공자) 고객의 개인신용정보 전송요구에 따라 보유하고 있는 고객의 개인신용\n정보를 정보수신자에게 전송하는 자(신용정보법 상 신용정보제공·이용자)'},
#   {'bounding_box': [{'x': 164, 'y': 958},
#     {'x': 1026, 'y': 958},
#     {'x': 1026, 'y': 1038},
#     {'x': 164, 'y': 1038}],
#    'category': 'list',
#    'html': "<p id='7' data-category='list' style='font-size:18px'>- (정보수신자) 고객의 개인신용정보 전송요구에 따라 정보제공자로부터 고객의 개인<br>신용정보를 제공받는 자</p>",
#    'id': 54,
#    'page': 12,
#    'text': '- (정보수신자) 고객의 개인신용정보 전송요구에 따라 정보제공자로부터 고객의 개인\n신용정보를 제공받는 자'},
#   {'bounding_box': [{'x': 164, 'y': 1088},
#     {'x': 1025, 'y': 1088},
#     {'x': 1025, 'y': 1169},
#     {'x': 164, 'y': 1169}],
#    'category': 'list',
#    'html': "<p id='8' data-category='list' style='font-size:18px'>- (마이데이터사업자) 금융위원회로부터 본인신용정보업 허가를 받아 고객에게 개인<br>신용정보 통합조회서비스(이하 마이데이터서비스)를 제공하는 자</p>",
#    'id': 55,
#    'page': 12,
#    'text': '- (마이데이터사업자) 금융위원회로부터 본인신용정보업 허가를 받아 고객에게 개인\n신용정보 통합조회서비스(이하 마이데이터서비스)를 제공하는 자'},
#   {'bounding_box': [{'x': 165, 'y': 1218},
#     {'x': 1026, 'y': 1218},
#     {'x': 1026, 'y': 1297},
#     {'x': 165, 'y': 1297}],
#    'category': 'list',
#    'html': "<p id='9' data-category='list' style='font-size:18px'>- (마이데이터서비스) 개인신용정보 통합조회서비스 등 마이데이터사업자가 고객에게<br>제공하는 서비스</p>",
#    'id': 56,
#    'page': 12,
#    'text': '- (마이데이터서비스) 개인신용정보 통합조회서비스 등 마이데이터사업자가 고객에게\n제공하는 서비스'},
#   {'bounding_box': [{'x': 130, 'y': 1480},
#     {'x': 230, 'y': 1480},
#     {'x': 230, 'y': 1506},
#     {'x': 130, 'y': 1506}],
#    'category': 'footer',
#    'html': "<footer id='10' style='font-size:14px'>4 금융보안원</footer>",
#    'id': 57,
#    'page': 12,
#    'text': '4 금융보안원'}],
#  13: [{'bounding_box': [{'x': 958, 'y': 143},
#     {'x': 1025, 'y': 143},
#     {'x': 1025, 'y': 169},
#     {'x': 958, 'y': 169}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:16px'>1장. 개요</p>",
#    'id': 58,
#    'page': 13,
#    'text': '1장. 개요'},
#   {'bounding_box': [{'x': 166, 'y': 226},
#     {'x': 1026, 'y': 226},
#     {'x': 1026, 'y': 392},
#     {'x': 166, 'y': 392}],
#    'category': 'paragraph',
#    'html': "<p id='1' data-category='paragraph' style='font-size:22px'>- (개인신용정보 전송요구) 고객이 자기결정에 따라 해당 고객의 개인신용정보를<br>보유하고 있는자(이하 정보제공자)로부터 해당 고객의 개인신용정보를 받을<br>자격이 있는 제3자(이하 정보수신자)에게 전송할 것을 요구하는 행위(신용정보법<br>제33조의2①)</p>",
#    'id': 59,
#    'page': 13,
#    'text': '- (개인신용정보 전송요구) 고객이 자기결정에 따라 해당 고객의 개인신용정보를\n보유하고 있는자(이하 정보제공자)로부터 해당 고객의 개인신용정보를 받을\n자격이 있는 제3자(이하 정보수신자)에게 전송할 것을 요구하는 행위(신용정보법\n제33조의2①)'},
#   {'bounding_box': [{'x': 166, 'y': 443},
#     {'x': 1026, 'y': 443},
#     {'x': 1026, 'y': 564},
#     {'x': 166, 'y': 564}],
#    'category': 'paragraph',
#    'html': "<p id='2' data-category='paragraph' style='font-size:20px'>- (본인인증) 고객이 정보제공자에게 개인신용정보 전송을 요구할 때, 고객이 해당<br>개인신용정보의 소유자임을 정보제공자가 확인하기 위한 방법(개별인증과 통합<br>인증으로 구분)</p>",
#    'id': 60,
#    'page': 13,
#    'text': '- (본인인증) 고객이 정보제공자에게 개인신용정보 전송을 요구할 때, 고객이 해당\n개인신용정보의 소유자임을 정보제공자가 확인하기 위한 방법(개별인증과 통합\n인증으로 구분)'},
#   {'bounding_box': [{'x': 195, 'y': 572},
#     {'x': 1026, 'y': 572},
#     {'x': 1026, 'y': 783},
#     {'x': 195, 'y': 783}],
#    'category': 'list',
#    'html': "<p id='3' data-category='list' style='font-size:20px'>· (개별인증) 정보제공자가 자율적으로 제공하는 인증수단을 이용한 본인인증<br>방법으로 고객이 개인신용정보 전송을 요구하는 정보제공자의 수만큼 인증이<br>이루어지는 방식<br>· (통합인증) 고객이 공용의 인증수단을 이용하여 인증행위를 1 회 수행함으로서<br>다수의 정보제공자에 인증이 가능한 방식</p>",
#    'id': 61,
#    'page': 13,
#    'text': '· (개별인증) 정보제공자가 자율적으로 제공하는 인증수단을 이용한 본인인증\n방법으로 고객이 개인신용정보 전송을 요구하는 정보제공자의 수만큼 인증이\n이루어지는 방식\n· (통합인증) 고객이 공용의 인증수단을 이용하여 인증행위를 1 회 수행함으로서\n다수의 정보제공자에 인증이 가능한 방식'},
#   {'bounding_box': [{'x': 166, 'y': 833},
#     {'x': 1025, 'y': 833},
#     {'x': 1025, 'y': 912},
#     {'x': 166, 'y': 912}],
#    'category': 'paragraph',
#    'html': "<p id='4' data-category='paragraph' style='font-size:18px'>- (개인신용정보 전송) 고객의 개인신용정보 전송요구에 따라 정보제공자로부터 정보<br>수신자로 개인신용정보가 전송되는 과정</p>",
#    'id': 62,
#    'page': 13,
#    'text': '- (개인신용정보 전송) 고객의 개인신용정보 전송요구에 따라 정보제공자로부터 정보\n수신자로 개인신용정보가 전송되는 과정'},
#   {'bounding_box': [{'x': 163, 'y': 963},
#     {'x': 1026, 'y': 963},
#     {'x': 1026, 'y': 1045},
#     {'x': 163, 'y': 1045}],
#    'category': 'list',
#    'html': "<p id='5' data-category='list' style='font-size:20px'>- (API, Application Programming Interface) 마이데이터사업자와 정보제공자간<br>개인신용정보를 송수신하기 위한 미리 정의된 표준화된 전송규격 및 절차</p>",
#    'id': 63,
#    'page': 13,
#    'text': '- (API, Application Programming Interface) 마이데이터사업자와 정보제공자간\n개인신용정보를 송수신하기 위한 미리 정의된 표준화된 전송규격 및 절차'},
#   {'bounding_box': [{'x': 164, 'y': 1093},
#     {'x': 1026, 'y': 1093},
#     {'x': 1026, 'y': 1217},
#     {'x': 164, 'y': 1217}],
#    'category': 'list',
#    'html': "<p id='6' data-category='list' style='font-size:20px'>- (마이데이터 종합포털) 마이데이터 산업 참여기관의 등록 및 관리, 자격증명의 발급<br>및 관리, 고객의 개인신용정보 전송요구내역 통합조회 서비스 등을 제공하는 마이<br>데이터 지원센터가 제공하는 웹 기반 서비스 (이하 종합포털)</p>",
#    'id': 64,
#    'page': 13,
#    'text': '- (마이데이터 종합포털) 마이데이터 산업 참여기관의 등록 및 관리, 자격증명의 발급\n및 관리, 고객의 개인신용정보 전송요구내역 통합조회 서비스 등을 제공하는 마이\n데이터 지원센터가 제공하는 웹 기반 서비스 (이하 종합포털)'},
#   {'bounding_box': [{'x': 164, 'y': 1265},
#     {'x': 1024, 'y': 1265},
#     {'x': 1024, 'y': 1346},
#     {'x': 164, 'y': 1346}],
#    'category': 'list',
#    'html': "<p id='7' data-category='list' style='font-size:20px'>- (중계기관) 마이데이터사업자의 API 요청에 대해 하나 이상의 정보제공자를 대신하여<br>고객의 개인신용정보를 중계하는 신용정보법 상 기관</p>",
#    'id': 65,
#    'page': 13,
#    'text': '- (중계기관) 마이데이터사업자의 API 요청에 대해 하나 이상의 정보제공자를 대신하여\n고객의 개인신용정보를 중계하는 신용정보법 상 기관'},
#   {'bounding_box': [{'x': 811, 'y': 1481},
#     {'x': 1026, 'y': 1481},
#     {'x': 1026, 'y': 1507},
#     {'x': 811, 'y': 1507}],
#    'category': 'footer',
#    'html': "<footer id='8' style='font-size:14px'>Financial Security Institute 5</footer>",
#    'id': 66,
#    'page': 13,
#    'text': 'Financial Security Institute 5'}],
#  14: [{'bounding_box': [{'x': 129, 'y': 142},
#     {'x': 401, 'y': 142},
#     {'x': 401, 'y': 169},
#     {'x': 129, 'y': 169}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:16px'>금융분야 마이데이터 기술 가이드라인</p>",
#    'id': 67,
#    'page': 14,
#    'text': '금융분야 마이데이터 기술 가이드라인'},
#   {'bounding_box': [{'x': 166, 'y': 227},
#     {'x': 1024, 'y': 227},
#     {'x': 1024, 'y': 306},
#     {'x': 166, 'y': 306}],
#    'category': 'heading1',
#    'html': "<h1 id='1' style='font-size:20px'>- (거점중계기관) 정보제공자를 대신하여 고객의 전송 요구에 따라 개인신용정보를<br>마이데이터사업자를 제외한 정보수신자에게 전송하는 기관</h1>",
#    'id': 68,
#    'page': 14,
#    'text': '- (거점중계기관) 정보제공자를 대신하여 고객의 전송 요구에 따라 개인신용정보를\n마이데이터사업자를 제외한 정보수신자에게 전송하는 기관'},
#   {'bounding_box': [{'x': 164, 'y': 356},
#     {'x': 1026, 'y': 356},
#     {'x': 1026, 'y': 434},
#     {'x': 164, 'y': 434}],
#    'category': 'list',
#    'html': "<p id='2' data-category='list' style='font-size:20px'>- (인증기관) 통합인증을 위한 본인인증수단을 발급하고, 발급된 인증수단을 관리<br>하는 기관</p>",
#    'id': 69,
#    'page': 14,
#    'text': '- (인증기관) 통합인증을 위한 본인인증수단을 발급하고, 발급된 인증수단을 관리\n하는 기관'},
#   {'bounding_box': [{'x': 166, 'y': 487},
#     {'x': 1025, 'y': 487},
#     {'x': 1025, 'y': 566},
#     {'x': 166, 'y': 566}],
#    'category': 'paragraph',
#    'html': "<p id='3' data-category='paragraph' style='font-size:20px'>- (TLS 인증서) 정보제공자와 마이데이터사업자 간 개인신용정보 전송 시 상호인증<br>및 암호화 채널 형성을 위한 인증서</p>",
#    'id': 70,
#    'page': 14,
#    'text': '- (TLS 인증서) 정보제공자와 마이데이터사업자 간 개인신용정보 전송 시 상호인증\n및 암호화 채널 형성을 위한 인증서'},
#   {'bounding_box': [{'x': 164, 'y': 616},
#     {'x': 1025, 'y': 616},
#     {'x': 1025, 'y': 696},
#     {'x': 164, 'y': 696}],
#    'category': 'paragraph',
#    'html': "<p id='4' data-category='paragraph' style='font-size:18px'>- (자격증명) API 요청시 상호간 자격을 인증하고 식별하기 위해 종합포털로부터<br>발급받는 값</p>",
#    'id': 71,
#    'page': 14,
#    'text': '- (자격증명) API 요청시 상호간 자격을 인증하고 식별하기 위해 종합포털로부터\n발급받는 값'},
#   {'bounding_box': [{'x': 165, 'y': 746},
#     {'x': 1026, 'y': 746},
#     {'x': 1026, 'y': 868},
#     {'x': 165, 'y': 868}],
#    'category': 'paragraph',
#    'html': "<p id='5' data-category='paragraph' style='font-size:20px'>- (접근토큰) API를 이용하여 개인신용정보 전송을 요청한 마이데이터사업자가 정보<br>제공자가 보유하고 있는 해당 고객의 개인신용정보에 접근할 수 있는 자격이 있는지를<br>확인하기 위해 발급받는 정보</p>",
#    'id': 72,
#    'page': 14,
#    'text': '- (접근토큰) API를 이용하여 개인신용정보 전송을 요청한 마이데이터사업자가 정보\n제공자가 보유하고 있는 해당 고객의 개인신용정보에 접근할 수 있는 자격이 있는지를\n확인하기 위해 발급받는 정보'},
#   {'bounding_box': [{'x': 131, 'y': 1480},
#     {'x': 229, 'y': 1480},
#     {'x': 229, 'y': 1506},
#     {'x': 131, 'y': 1506}],
#    'category': 'footer',
#    'html': "<footer id='6' style='font-size:14px'>6 금융보안원</footer>",
#    'id': 73,
#    'page': 14,
#    'text': '6 금융보안원'}],
#  15: [{'bounding_box': [{'x': 937, 'y': 566},
#     {'x': 1027, 'y': 566},
#     {'x': 1027, 'y': 601},
#     {'x': 937, 'y': 601}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:14px'>PART.</p>",
#    'id': 74,
#    'page': 15,
#    'text': 'PART.'},
#   {'bounding_box': [{'x': 216, 'y': 603},
#     {'x': 632, 'y': 603},
#     {'x': 632, 'y': 669},
#     {'x': 216, 'y': 669}],
#    'category': 'heading1',
#    'html': "<br><h1 id='1' style='font-size:18px'>개인신용정보 전송</h1>",
#    'id': 75,
#    'page': 15,
#    'text': '개인신용정보 전송'},
#   {'bounding_box': [{'x': 222, 'y': 758},
#     {'x': 737, 'y': 758},
#     {'x': 737, 'y': 1055},
#     {'x': 222, 'y': 1055}],
#    'category': 'index',
#    'html': "<p id='2' data-category='index' style='font-size:16px'>2.1. 개인신용정보 전송 개요 8<br>2.2. 개인신용정보 전송 원칙 14<br>2.3. 개인신용정보 전송 방식 20<br>2.4. 개인신용정보 전송 유형 21<br>2.5. 전송 유형별 전송 절차 및 규격 24</p>",
#    'id': 76,
#    'page': 15,
#    'text': '2.1. 개인신용정보 전송 개요 8\n2.2. 개인신용정보 전송 원칙 14\n2.3. 개인신용정보 전송 방식 20\n2.4. 개인신용정보 전송 유형 21\n2.5. 전송 유형별 전송 절차 및 규격 24'},
#   {'bounding_box': [{'x': 849, 'y': 626},
#     {'x': 1039, 'y': 626},
#     {'x': 1039, 'y': 762},
#     {'x': 849, 'y': 762}],
#    'category': 'heading1',
#    'html': "<br><h1 id='3' style='font-size:20px'>02</h1>",
#    'id': 77,
#    'page': 15,
#    'text': '02'},
#   {'bounding_box': [{'x': 565, 'y': 1389},
#     {'x': 960, 'y': 1389},
#     {'x': 960, 'y': 1423},
#     {'x': 565, 'y': 1423}],
#    'category': 'paragraph',
#    'html': "<p id='4' data-category='paragraph' style='font-size:14px'>금융분야 마이데이터 기술 가이드라인</p>",
#    'id': 78,
#    'page': 15,
#    'text': '금융분야 마이데이터 기술 가이드라인'}],
#  16: [{'bounding_box': [{'x': 129, 'y': 142},
#     {'x': 401, 'y': 142},
#     {'x': 401, 'y': 169},
#     {'x': 129, 'y': 169}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:14px'>금융분야 마이데이터 기술 가이드라인</p>",
#    'id': 79,
#    'page': 16,
#    'text': '금융분야 마이데이터 기술 가이드라인'},
#   {'bounding_box': [{'x': 171, 'y': 254},
#     {'x': 204, 'y': 254},
#     {'x': 204, 'y': 297},
#     {'x': 171, 'y': 297}],
#    'category': 'heading1',
#    'html': "<h1 id='1' style='font-size:22px'>2</h1>",
#    'id': 80,
#    'page': 16,
#    'text': '2'},
#   {'bounding_box': [{'x': 248, 'y': 256},
#     {'x': 516, 'y': 256},
#     {'x': 516, 'y': 295},
#     {'x': 248, 'y': 295}],
#    'category': 'heading1',
#    'html': "<br><h1 id='2' style='font-size:20px'>개인신용정보 전송</h1>",
#    'id': 81,
#    'page': 16,
#    'text': '개인신용정보 전송'},
#   {'bounding_box': [{'x': 144, 'y': 390},
#     {'x': 1010, 'y': 390},
#     {'x': 1010, 'y': 543},
#     {'x': 144, 'y': 543}],
#    'category': 'paragraph',
#    'html': "<p id='3' data-category='paragraph' style='font-size:16px'>본 장은 고객, 정보제공자, 정보수신자간에 이루어지는 개인신용정보 전송 원칙과 각 유형별 전송 절차를<br>다룬다<br>각 유형별 전송규격 및 절차는 별도의 규격을 참조할 필요가 있으며, API 규격을 이용한 마이데이터<br>서비스 절차는 3장에서 설명한다.</p>",
#    'id': 82,
#    'page': 16,
#    'text': '본 장은 고객, 정보제공자, 정보수신자간에 이루어지는 개인신용정보 전송 원칙과 각 유형별 전송 절차를\n다룬다\n각 유형별 전송규격 및 절차는 별도의 규격을 참조할 필요가 있으며, API 규격을 이용한 마이데이터\n서비스 절차는 3장에서 설명한다.'},
#   {'bounding_box': [{'x': 130, 'y': 652},
#     {'x': 522, 'y': 652},
#     {'x': 522, 'y': 695},
#     {'x': 130, 'y': 695}],
#    'category': 'heading1',
#    'html': "<h1 id='4' style='font-size:20px'>2.1. 개인신용정보 전송 개요</h1>",
#    'id': 83,
#    'page': 16,
#    'text': '2.1. 개인신용정보 전송 개요'},
#   {'bounding_box': [{'x': 127, 'y': 737},
#     {'x': 1025, 'y': 737},
#     {'x': 1025, 'y': 819},
#     {'x': 127, 'y': 819}],
#    'category': 'paragraph',
#    'html': "<p id='5' data-category='paragraph' style='font-size:18px'>개인신용정보 전송은 ①개인신용정보 전송요구, ② 고객 본인인증 ③개인신용정보 전송의<br>3단계로 이루어진다.</p>",
#    'id': 84,
#    'page': 16,
#    'text': '개인신용정보 전송은 ①개인신용정보 전송요구, ② 고객 본인인증 ③개인신용정보 전송의\n3단계로 이루어진다.'},
#   {'bounding_box': [{'x': 450, 'y': 870},
#     {'x': 705, 'y': 870},
#     {'x': 705, 'y': 902},
#     {'x': 450, 'y': 902}],
#    'category': 'heading1',
#    'html': "<h1 id='6' style='font-size:16px'>개인신용정보 전송 절차 ></h1>",
#    'id': 85,
#    'page': 16,
#    'text': '개인신용정보 전송 절차 >'},
#   {'bounding_box': [{'x': 135, 'y': 910},
#     {'x': 1013, 'y': 910},
#     {'x': 1013, 'y': 1031},
#     {'x': 135, 'y': 1031}],
#    'category': 'figure',
#    'html': '<br><figure><img id=\'7\' style=\'font-size:16px\' alt="가 나 다\n개인신용정보 전송요구 고객 본인인증 개인신용정보 전송" data-coord="top-left:(135,910); bottom-right:(1013,1031)" /></figure>',
#    'id': 86,
#    'page': 16,
#    'text': '가 나 다\n개인신용정보 전송요구 고객 본인인증 개인신용정보 전송'},
#   {'bounding_box': [{'x': 129, 'y': 1089},
#     {'x': 450, 'y': 1089},
#     {'x': 450, 'y': 1132},
#     {'x': 129, 'y': 1132}],
#    'category': 'heading1',
#    'html': "<h1 id='8' style='font-size:18px'>가. 개인신용정보 전송요구</h1>",
#    'id': 87,
#    'page': 16,
#    'text': '가. 개인신용정보 전송요구'},
#   {'bounding_box': [{'x': 128, 'y': 1166},
#     {'x': 1026, 'y': 1166},
#     {'x': 1026, 'y': 1245},
#     {'x': 128, 'y': 1245}],
#    'category': 'paragraph',
#    'html': "<p id='9' data-category='paragraph' style='font-size:16px'>(개인신용정보 전송요구) 고객은 정보제공자에게 본인의 개인신용정보를 정보수신자에<br>전송할 것을 요구할 수 있다.</p>",
#    'id': 88,
#    'page': 16,
#    'text': '(개인신용정보 전송요구) 고객은 정보제공자에게 본인의 개인신용정보를 정보수신자에\n전송할 것을 요구할 수 있다.'},
#   {'bounding_box': [{'x': 131, 'y': 1480},
#     {'x': 229, 'y': 1480},
#     {'x': 229, 'y': 1506},
#     {'x': 131, 'y': 1506}],
#    'category': 'footer',
#    'html': "<footer id='10' style='font-size:14px'>8 금융보안원</footer>",
#    'id': 89,
#    'page': 16,
#    'text': '8 금융보안원'}],
#  17: [{'bounding_box': [{'x': 868, 'y': 143},
#     {'x': 1024, 'y': 143},
#     {'x': 1024, 'y': 170},
#     {'x': 868, 'y': 170}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:14px'>2장. 개인신용정보 전송</p>",
#    'id': 90,
#    'page': 17,
#    'text': '2장. 개인신용정보 전송'},
#   {'bounding_box': [{'x': 128, 'y': 226},
#     {'x': 653, 'y': 226},
#     {'x': 653, 'y': 258},
#     {'x': 128, 'y': 258}],
#    'category': 'heading1',
#    'html': "<h1 id='1' style='font-size:18px'>〈 개인신용정보 전송 시 정보제공자 및 정보수신자 예시 ></h1>",
#    'id': 91,
#    'page': 17,
#    'text': '〈 개인신용정보 전송 시 정보제공자 및 정보수신자 예시 >'},
#   {'bounding_box': [{'x': 131, 'y': 269},
#     {'x': 1026, 'y': 269},
#     {'x': 1026, 'y': 431},
#     {'x': 131, 'y': 431}],
#    'category': 'table',
#    'html': "<br><table id='2' style='font-size:16px'><tr><td>분류</td><td>예시</td></tr><tr><td>정보제공자</td><td>금융회사, 공공기관, 마이데이터사업자 등</td></tr><tr><td>정보수신자</td><td>고객, 마이데이터사업자, 금융회사 등</td></tr></table>",
#    'id': 92,
#    'page': 17,
#    'text': '분류 예시\n 정보제공자 금융회사, 공공기관, 마이데이터사업자 등\n 정보수신자 고객, 마이데이터사업자, 금융회사 등'},
#   {'bounding_box': [{'x': 130, 'y': 442},
#     {'x': 959, 'y': 442},
#     {'x': 959, 'y': 472},
#     {'x': 130, 'y': 472}],
#    'category': 'paragraph',
#    'html': "<br><p id='3' data-category='paragraph' style='font-size:16px'>※ 개인신용정보를 제공 및 수신할 수 있는 전체 대상은 「[참고1] 정보제공자 ·정보수신자 범위」 참조</p>",
#    'id': 93,
#    'page': 17,
#    'text': '※ 개인신용정보를 제공 및 수신할 수 있는 전체 대상은 「[참고1] 정보제공자 ·정보수신자 범위」 참조'},
#   {'bounding_box': [{'x': 157, 'y': 529},
#     {'x': 197, 'y': 529},
#     {'x': 197, 'y': 563},
#     {'x': 157, 'y': 563}],
#    'category': 'heading1',
#    'html': "<h1 id='4' style='font-size:18px'>! D·</h1>",
#    'id': 94,
#    'page': 17,
#    'text': '! D·'},
#   {'bounding_box': [{'x': 215, 'y': 528},
#     {'x': 319, 'y': 528},
#     {'x': 319, 'y': 556},
#     {'x': 215, 'y': 556}],
#    'category': 'heading1',
#    'html': "<br><h1 id='5' style='font-size:20px'>관련법령</h1>",
#    'id': 95,
#    'page': 17,
#    'text': '관련법령'},
#   {'bounding_box': [{'x': 177, 'y': 600},
#     {'x': 990, 'y': 600},
#     {'x': 990, 'y': 702},
#     {'x': 177, 'y': 702}],
#    'category': 'paragraph',
#    'html': "<p id='6' data-category='paragraph' style='font-size:18px'>신용정보법 제33조의2(개인신용정보의 전송요구) ① 개인인 신용정보주체는 신용정보제공·<br>이용자등에 대하여 그가 보유하고 있는 본인에 관한 개인신용정보를 다음 각 호의 어느 하나에<br>해당하는 자에게 전송하여 줄 것을 요구할 수 있다.</p>",
#    'id': 96,
#    'page': 17,
#    'text': '신용정보법 제33조의2(개인신용정보의 전송요구) ① 개인인 신용정보주체는 신용정보제공·\n이용자등에 대하여 그가 보유하고 있는 본인에 관한 개인신용정보를 다음 각 호의 어느 하나에\n해당하는 자에게 전송하여 줄 것을 요구할 수 있다.'},
#   {'bounding_box': [{'x': 194, 'y': 715},
#     {'x': 931, 'y': 715},
#     {'x': 931, 'y': 897},
#     {'x': 194, 'y': 897}],
#    'category': 'list',
#    'html': "<br><p id='7' data-category='list' style='font-size:14px'>1. 해당 신용정보주체 본인<br>2. 본인신용정보관리회사<br>3. 대통령령으로 정하는 신용정보제공·이용자<br>4. 개인신용평가회사<br>5. 그 밖에 제1 호부터 제4호까지의 규정에서 정한 자와 유사한 자로서 대통령령으로 정하는 자</p>",
#    'id': 97,
#    'page': 17,
#    'text': '1. 해당 신용정보주체 본인\n2. 본인신용정보관리회사\n3. 대통령령으로 정하는 신용정보제공·이용자\n4. 개인신용평가회사\n5. 그 밖에 제1 호부터 제4호까지의 규정에서 정한 자와 유사한 자로서 대통령령으로 정하는 자'},
#   {'bounding_box': [{'x': 125, 'y': 1021},
#     {'x': 1026, 'y': 1021},
#     {'x': 1026, 'y': 1099},
#     {'x': 125, 'y': 1099}],
#    'category': 'paragraph',
#    'html': "<p id='8' data-category='paragraph' style='font-size:22px'>(전송 요구 방법) 고객은 정보제공자를 통해 비대면 방식으로 개인신용정보 전송을<br>요구할 수 있다.</p>",
#    'id': 98,
#    'page': 17,
#    'text': '(전송 요구 방법) 고객은 정보제공자를 통해 비대면 방식으로 개인신용정보 전송을\n요구할 수 있다.'},
#   {'bounding_box': [{'x': 163, 'y': 1152},
#     {'x': 897, 'y': 1152},
#     {'x': 897, 'y': 1187},
#     {'x': 163, 'y': 1187}],
#    'category': 'paragraph',
#    'html': "<p id='9' data-category='paragraph' style='font-size:18px'>※ 금융회사 창구등을 통한 대면 전송요구 방식은 제반여건에 따라 추후 검토</p>",
#    'id': 99,
#    'page': 17,
#    'text': '※ 금융회사 창구등을 통한 대면 전송요구 방식은 제반여건에 따라 추후 검토'},
#   {'bounding_box': [{'x': 811, 'y': 1481},
#     {'x': 1025, 'y': 1481},
#     {'x': 1025, 'y': 1507},
#     {'x': 811, 'y': 1507}],
#    'category': 'footer',
#    'html': "<footer id='10' style='font-size:14px'>Financial Security Institute 9</footer>",
#    'id': 100,
#    'page': 17,
#    'text': 'Financial Security Institute 9'}],
#  18: [{'bounding_box': [{'x': 129, 'y': 142},
#     {'x': 401, 'y': 142},
#     {'x': 401, 'y': 169},
#     {'x': 129, 'y': 169}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:14px'>금융분야 마이데이터 기술 가이드라인</p>",
#    'id': 101,
#    'page': 18,
#    'text': '금융분야 마이데이터 기술 가이드라인'},
#   {'bounding_box': [{'x': 132, 'y': 225},
#     {'x': 1026, 'y': 225},
#     {'x': 1026, 'y': 305},
#     {'x': 132, 'y': 305}],
#    'category': 'paragraph',
#    'html': "<p id='1' data-category='paragraph' style='font-size:20px'>(전송 요구 사항) 고객은 개인신용정보 전송요구 시 아래와 같이 법령상 요구하는 내용을<br>특정하여야 한다.</p>",
#    'id': 102,
#    'page': 18,
#    'text': '(전송 요구 사항) 고객은 개인신용정보 전송요구 시 아래와 같이 법령상 요구하는 내용을\n특정하여야 한다.'},
#   {'bounding_box': [{'x': 162, 'y': 355},
#     {'x': 1024, 'y': 355},
#     {'x': 1024, 'y': 436},
#     {'x': 162, 'y': 436}],
#    'category': 'paragraph',
#    'html': "<p id='2' data-category='paragraph' style='font-size:20px'>- (전송 요구 화면 구성) 정보제공자는 고객이 전송요구 사항을 안전하고 편리하게<br>특정할 수 있도록 관련 양식, 화면 등을 제공해야 한다.</p>",
#    'id': 103,
#    'page': 18,
#    'text': '- (전송 요구 화면 구성) 정보제공자는 고객이 전송요구 사항을 안전하고 편리하게\n특정할 수 있도록 관련 양식, 화면 등을 제공해야 한다.'},
#   {'bounding_box': [{'x': 130, 'y': 486},
#     {'x': 372, 'y': 486},
#     {'x': 372, 'y': 518},
#     {'x': 130, 'y': 518}],
#    'category': 'heading1',
#    'html': "<h1 id='3' style='font-size:16px'>〈 전송요구 시 특정 정보 ></h1>",
#    'id': 104,
#    'page': 18,
#    'text': '〈 전송요구 시 특정 정보 >'},
#   {'bounding_box': [{'x': 128, 'y': 527},
#     {'x': 1025, 'y': 527},
#     {'x': 1025, 'y': 1267},
#     {'x': 128, 'y': 1267}],
#    'category': 'table',
#    'html': "<table id='4' style='font-size:14px'><tr><td>분류</td><td>내용</td><td>비고</td></tr><tr><td>전송요구를 받는 자</td><td>개인신용정보를 보유하고 있는 정보제공자</td><td>· 정보제공자(상호/명칭)</td></tr><tr><td>개인신용정보를 제공받는 자</td><td>개인신용정보를 전송받는 정보수신자 (고객, 마이데이터사업자, 기타수신자 등)</td><td>· 정보수신자(상호/명칭)</td></tr><tr><td>전송을 요구하는 개인신용정보</td><td>고객이 전송 요구하고자 하는 개인신용정보</td><td>· 정보의 항목</td></tr><tr><td>정기적 전송을 요구하는지 여부</td><td>개인신용정보의 정확성 및 최신성을 유지하기 위해서 정기적으로 개인신용정보를 전송 받을지 여부와 전송 주기</td><td>· 요구/미요구 · 주기(주1회)</td></tr><tr><td>전송요구 종료 시점</td><td>개인신용정보 전송 요구의 종료 시점</td><td>· 최대 1년</td></tr><tr><td>전송을 요구하는 목적</td><td>개인신용정보 전송을 요구하는 목적</td><td>· 전송요구를 통한 본인 신용정보 통합조회 서비스의 이용 · 데이터 분석 서비스의 이용</td></tr><tr><td>전송을 요구하는 개인신용정보의 보유기간</td><td>개인신용정보를 전송받은 정보수신자가 수집한 정보를 보유할 수 있는 기간</td><td>· 서비스 종료시 또는 삭제 요구시까지</td></tr></table>",
#    'id': 105,
#    'page': 18,
#    'text': '분류 내용 비고\n 전송요구를 받는 자 개인신용정보를 보유하고 있는 정보제공자 · 정보제공자(상호/명칭)\n 개인신용정보를 제공받는 자 개인신용정보를 전송받는 정보수신자 (고객, 마이데이터사업자, 기타수신자 등) · 정보수신자(상호/명칭)\n 전송을 요구하는 개인신용정보 고객이 전송 요구하고자 하는 개인신용정보 · 정보의 항목\n 정기적 전송을 요구하는지 여부 개인신용정보의 정확성 및 최신성을 유지하기 위해서 정기적으로 개인신용정보를 전송 받을지 여부와 전송 주기 · 요구/미요구 · 주기(주1회)\n 전송요구 종료 시점 개인신용정보 전송 요구의 종료 시점 · 최대 1년\n 전송을 요구하는 목적 개인신용정보 전송을 요구하는 목적 · 전송요구를 통한 본인 신용정보 통합조회 서비스의 이용 · 데이터 분석 서비스의 이용\n 전송을 요구하는 개인신용정보의 보유기간 개인신용정보를 전송받은 정보수신자가 수집한 정보를 보유할 수 있는 기간 · 서비스 종료시 또는 삭제 요구시까지'},
#   {'bounding_box': [{'x': 130, 'y': 1275},
#     {'x': 777, 'y': 1275},
#     {'x': 777, 'y': 1309},
#     {'x': 130, 'y': 1309}],
#    'category': 'paragraph',
#    'html': "<br><p id='5' data-category='paragraph' style='font-size:18px'>※ 특정 정보에 대한 상세 구성은 신용정보원의 '알고하는 동의' 참조</p>",
#    'id': 106,
#    'page': 18,
#    'text': "※ 특정 정보에 대한 상세 구성은 신용정보원의 '알고하는 동의' 참조"},
#   {'bounding_box': [{'x': 131, 'y': 1479},
#     {'x': 241, 'y': 1479},
#     {'x': 241, 'y': 1507},
#     {'x': 131, 'y': 1507}],
#    'category': 'footer',
#    'html': "<footer id='6' style='font-size:14px'>10 금융보안원</footer>",
#    'id': 107,
#    'page': 18,
#    'text': '10 금융보안원'}],
#  19: [{'bounding_box': [{'x': 868, 'y': 143},
#     {'x': 1024, 'y': 143},
#     {'x': 1024, 'y': 170},
#     {'x': 868, 'y': 170}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:14px'>2장. 개인신용정보 전송</p>",
#    'id': 108,
#    'page': 19,
#    'text': '2장. 개인신용정보 전송'},
#   {'bounding_box': [{'x': 214, 'y': 238},
#     {'x': 319, 'y': 238},
#     {'x': 319, 'y': 266},
#     {'x': 214, 'y': 266}],
#    'category': 'paragraph',
#    'html': "<p id='1' data-category='paragraph' style='font-size:18px'>관련법령</p>",
#    'id': 109,
#    'page': 19,
#    'text': '관련법령'},
#   {'bounding_box': [{'x': 163, 'y': 247},
#     {'x': 176, 'y': 247},
#     {'x': 176, 'y': 269},
#     {'x': 163, 'y': 269}],
#    'category': 'paragraph',
#    'html': "<br><p id='2' data-category='paragraph' style='font-size:16px'>!</p>",
#    'id': 110,
#    'page': 19,
#    'text': '!'},
#   {'bounding_box': [{'x': 177, 'y': 309},
#     {'x': 993, 'y': 309},
#     {'x': 993, 'y': 411},
#     {'x': 177, 'y': 411}],
#    'category': 'paragraph',
#    'html': "<p id='3' data-category='paragraph' style='font-size:18px'>신용정보법 제33조의2(개인신용정보의 전송요구) ⑤ 개인인 신용정보주체가 제1항 각 호의<br>어느 하나에 해당하는 자에게 제1 항에 따른 전송요구를 할 때에는 다음 각 호의 사항을 모두<br>특정하여 전자문서나 그 밖에 안전성과 신뢰성이 확보된 방법으로 하여야 한다.</p>",
#    'id': 111,
#    'page': 19,
#    'text': '신용정보법 제33조의2(개인신용정보의 전송요구) ⑤ 개인인 신용정보주체가 제1항 각 호의\n어느 하나에 해당하는 자에게 제1 항에 따른 전송요구를 할 때에는 다음 각 호의 사항을 모두\n특정하여 전자문서나 그 밖에 안전성과 신뢰성이 확보된 방법으로 하여야 한다.'},
#   {'bounding_box': [{'x': 194, 'y': 423},
# ...
#     {'x': 914, 'y': 227},
#     {'x': 914, 'y': 271},
#     {'x': 129, 'y': 271}],
#    'category': 'heading1',
#    'html': "<h1 id='1' style='font-size:22px'>참고 3. 주요 인증 규격(가이드라인)의 인증 수준 요구 현황</h1>",
#    'id': 1241,
#    'page': 129,
#    'text': '참고 3. 주요 인증 규격(가이드라인)의 인증 수준 요구 현황'},
#   {'bounding_box': [{'x': 126, 'y': 315},
#     {'x': 722, 'y': 315},
#     {'x': 722, 'y': 352},
#     {'x': 126, 'y': 352}],
#    'category': 'heading1',
#    'html': "<h1 id='2' style='font-size:20px'>미국 NIST, 디지털 신원 가이드라인(SP 8000-63-3)</h1>",
#    'id': 1242,
#    'page': 129,
#    'text': '미국 NIST, 디지털 신원 가이드라인(SP 8000-63-3)'},
#   {'bounding_box': [{'x': 163, 'y': 401},
#     {'x': 1026, 'y': 401},
#     {'x': 1026, 'y': 483},
#     {'x': 163, 'y': 483}],
#    'category': 'paragraph',
#    'html': "<p id='3' data-category='paragraph' style='font-size:18px'>- 인증을 통해 개인정보에 접근 가능한 경우 등에는 다중 인증에 해당하는 AAL 2<br>이상에 해당하는 인증 수단 적용</p>",
#    'id': 1243,
#    'page': 129,
#    'text': '- 인증을 통해 개인정보에 접근 가능한 경우 등에는 다중 인증에 해당하는 AAL 2\n이상에 해당하는 인증 수단 적용'},
#   {'bounding_box': [{'x': 130, 'y': 532},
#     {'x': 1025, 'y': 532},
#     {'x': 1025, 'y': 962},
#     {'x': 130, 'y': 962}],
#    'category': 'table',
#    'html': "<table id='4' style='font-size:14px'><tr><td>보증 수준</td><td>허가 인증 수단 (예시)</td></tr><tr><td>AAL* 3 (높음)</td><td>· OTP + 다중 요소 공개키 인증서(예: 전자서명 생성시 비밀번호 요구) · 공개키 인증서(보안 영역에 저장) + 비밀번호 · 다중 요소 공개키 인증서(보안 영역에 저장) · OTP + 공개키 인증서 + 비밀번호</td></tr><tr><td>AAL 2</td><td>· 다중 요소 OTP(예: OTP 생성시 비밀번호 요구) · 다중 요소 공개키 인증서 · 비밀번호 + 보안카드/OTP/공개키 인증서</td></tr><tr><td>AAL 1 (낮음)</td><td>· 비밀번호, 보안카드, OTP, 다중 요소 OTP, 공개키인증서 등</td></tr></table>",
#    'id': 1244,
#    'page': 129,
#    'text': '보증 수준 허가 인증 수단 (예시)\n AAL* 3 (높음) · OTP + 다중 요소 공개키 인증서(예: 전자서명 생성시 비밀번호 요구) · 공개키 인증서(보안 영역에 저장) + 비밀번호 · 다중 요소 공개키 인증서(보안 영역에 저장) · OTP + 공개키 인증서 + 비밀번호\n AAL 2 · 다중 요소 OTP(예: OTP 생성시 비밀번호 요구) · 다중 요소 공개키 인증서 · 비밀번호 + 보안카드/OTP/공개키 인증서\n AAL 1 (낮음) · 비밀번호, 보안카드, OTP, 다중 요소 OTP, 공개키인증서 등'},
#   {'bounding_box': [{'x': 131, 'y': 969},
#     {'x': 651, 'y': 969},
#     {'x': 651, 'y': 1000},
#     {'x': 131, 'y': 1000}],
#    'category': 'paragraph',
#    'html': "<p id='5' data-category='paragraph' style='font-size:14px'>* AAL(Authentication Assurance Level) - 인증 보증 수준</p>",
#    'id': 1245,
#    'page': 129,
#    'text': '* AAL(Authentication Assurance Level) - 인증 보증 수준'},
#   {'bounding_box': [{'x': 128, 'y': 1045},
#     {'x': 887, 'y': 1045},
#     {'x': 887, 'y': 1081},
#     {'x': 128, 'y': 1081}],
#    'category': 'paragraph',
#    'html': "<p id='6' data-category='paragraph' style='font-size:20px'>EU, PSD2 하위 강력한 고객인증(SCA) 등에 대한 규제기술표준(RTS)</p>",
#    'id': 1246,
#    'page': 129,
#    'text': 'EU, PSD2 하위 강력한 고객인증(SCA) 등에 대한 규제기술표준(RTS)'},
#   {'bounding_box': [{'x': 165, 'y': 1131},
#     {'x': 1026, 'y': 1131},
#     {'x': 1026, 'y': 1211},
#     {'x': 165, 'y': 1211}],
#    'category': 'paragraph',
#    'html': "<p id='7' data-category='paragraph' style='font-size:18px'>- 지급자(고객)가 자신의 온라인 지급계좌에 접근(지급지시, 거래내역 조회 등)하는<br>경우 다중 인증을 적용하도록 규정</p>",
#    'id': 1247,
#    'page': 129,
#    'text': '- 지급자(고객)가 자신의 온라인 지급계좌에 접근(지급지시, 거래내역 조회 등)하는\n경우 다중 인증을 적용하도록 규정'},
#   {'bounding_box': [{'x': 788, 'y': 1480},
#     {'x': 1025, 'y': 1480},
#     {'x': 1025, 'y': 1507},
#     {'x': 788, 'y': 1507}],
#    'category': 'footer',
#    'html': "<footer id='8' style='font-size:14px'>Financial Security Institute 121</footer>",
#    'id': 1248,
#    'page': 129,
#    'text': 'Financial Security Institute 121'}],
#  130: [{'bounding_box': [{'x': 129, 'y': 142},
#     {'x': 401, 'y': 142},
#     {'x': 401, 'y': 169},
#     {'x': 129, 'y': 169}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:18px'>금융분야 마이데이터 기술 가이드라인</p>",
#    'id': 1249,
#    'page': 130,
#    'text': '금융분야 마이데이터 기술 가이드라인'},
#   {'bounding_box': [{'x': 129, 'y': 227},
#     {'x': 676, 'y': 227},
#     {'x': 676, 'y': 262},
#     {'x': 129, 'y': 262}],
#    'category': 'paragraph',
#    'html': "<p id='1' data-category='paragraph' style='font-size:20px'>ISO/IEC:29115 실체 인증 보증 프레임워크 표준</p>",
#    'id': 1250,
#    'page': 130,
#    'text': 'ISO/IEC:29115 실체 인증 보증 프레임워크 표준'},
#   {'bounding_box': [{'x': 165, 'y': 312},
#     {'x': 1026, 'y': 312},
#     {'x': 1026, 'y': 393},
#     {'x': 165, 'y': 393}],
#    'category': 'paragraph',
#    'html': "<p id='2' data-category='paragraph' style='font-size:20px'>민감 개인정보 및 개인 경제활동 정보 접근시 다중 인증에 해당하는 LoA 3 이상에<br>해당하는 인증 요구사항 적용</p>",
#    'id': 1251,
#    'page': 130,
#    'text': '민감 개인정보 및 개인 경제활동 정보 접근시 다중 인증에 해당하는 LoA 3 이상에\n해당하는 인증 요구사항 적용'},
#   {'bounding_box': [{'x': 129, 'y': 444},
#     {'x': 1024, 'y': 444},
#     {'x': 1024, 'y': 892},
#     {'x': 129, 'y': 892}],
#    'category': 'table',
#    'html': "<table id='3' style='font-size:16px'><tr><td>보증 수준</td><td>인증 요구사항</td></tr><tr><td>LoA* 4 (높음)</td><td>· H/W 암호화 기반 인증수단 (전자서명 적용) · 대면인증 필수 또는 이에 준하는 수준의 신원확인</td></tr><tr><td>LoA 3</td><td>· 지식인증과 소유인증 필수 · 일반적인 수준 이상의 엄밀한 신원확인</td></tr><tr><td>LoA 2</td><td>· 소유 기반 인증 또는 이에 준하는 보안수단 필수 · 신원의 신뢰성 있음(일반적인 수준의 신뢰수준)</td></tr><tr><td>LoA 1 (낮음)</td><td>· ID/PW, 단일 요소 인증 · 신원확인절차가 없거나 신원의 신뢰성을 요하지 않음</td></tr></table>",
#    'id': 1252,
#    'page': 130,
#    'text': '보증 수준 인증 요구사항\n LoA* 4 (높음) · H/W 암호화 기반 인증수단 (전자서명 적용) · 대면인증 필수 또는 이에 준하는 수준의 신원확인\n LoA 3 · 지식인증과 소유인증 필수 · 일반적인 수준 이상의 엄밀한 신원확인\n LoA 2 · 소유 기반 인증 또는 이에 준하는 보안수단 필수 · 신원의 신뢰성 있음(일반적인 수준의 신뢰수준)\n LoA 1 (낮음) · ID/PW, 단일 요소 인증 · 신원확인절차가 없거나 신원의 신뢰성을 요하지 않음'},
#   {'bounding_box': [{'x': 129, 'y': 905},
#     {'x': 662, 'y': 905},
#     {'x': 662, 'y': 968},
#     {'x': 129, 'y': 968}],
#    'category': 'paragraph',
#    'html': "<p id='4' data-category='paragraph' style='font-size:14px'>* LoA(Level of Assurance) - 인증 보증 수준<br>※ 출처 - 공공웹사이트 인증 수단 소개서(행정안전부, 2018.9.)</p>",
#    'id': 1253,
#    'page': 130,
#    'text': '* LoA(Level of Assurance) - 인증 보증 수준\n※ 출처 - 공공웹사이트 인증 수단 소개서(행정안전부, 2018.9.)'},
#   {'bounding_box': [{'x': 132, 'y': 1479},
#     {'x': 252, 'y': 1479},
#     {'x': 252, 'y': 1507},
#     {'x': 132, 'y': 1507}],
#    'category': 'footer',
#    'html': "<footer id='5' style='font-size:16px'>122 금융보안원</footer>",
#    'id': 1254,
#    'page': 130,
#    'text': '122 금융보안원'}],
#  131: [{'bounding_box': [{'x': 957, 'y': 143},
#     {'x': 1026, 'y': 143},
#     {'x': 1026, 'y': 170},
#     {'x': 957, 'y': 170}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:14px'>7장. 참고</p>",
#    'id': 1255,
#    'page': 131,
#    'text': '7장. 참고'},
#   {'bounding_box': [{'x': 131, 'y': 228},
#     {'x': 533, 'y': 228},
#     {'x': 533, 'y': 270},
#     {'x': 131, 'y': 270}],
#    'category': 'heading1',
#    'html': "<h1 id='1' style='font-size:22px'>참고 4. 비대면 실명확인 방식</h1>",
#    'id': 1256,
#    'page': 131,
#    'text': '참고 4. 비대면 실명확인 방식'},
#   {'bounding_box': [{'x': 127, 'y': 315},
#     {'x': 1025, 'y': 315},
#     {'x': 1025, 'y': 395},
#     {'x': 127, 'y': 395}],
#    'category': 'list',
#    'html': "<p id='2' data-category='list' style='font-size:18px'>① 실명확인증표 사본 제출 : 고객이 실명확인증표(원본)를 사진촬영 또는 스캔 후 컴퓨터<br>또는 모바일 기기를 통해 이메일, 파일 업로드 등의 방식으로 제출</p>",
#    'id': 1257,
#    'page': 131,
#    'text': '① 실명확인증표 사본 제출 : 고객이 실명확인증표(원본)를 사진촬영 또는 스캔 후 컴퓨터\n또는 모바일 기기를 통해 이메일, 파일 업로드 등의 방식으로 제출'},
#   {'bounding_box': [{'x': 128, 'y': 445},
#     {'x': 1027, 'y': 445},
#     {'x': 1027, 'y': 523},
#     {'x': 128, 'y': 523}],
#    'category': 'heading1',
#    'html': "<h1 id='3' style='font-size:20px'>② 영상통화 금융회사 또는 금융회사 직원이 영상통화 등을 통해 실명확인증표상 사진과<br>고객의 얼굴을 대조</h1>",
#    'id': 1258,
#    'page': 131,
#    'text': '② 영상통화 금융회사 또는 금융회사 직원이 영상통화 등을 통해 실명확인증표상 사진과\n고객의 얼굴을 대조'},
#   {'bounding_box': [{'x': 164, 'y': 574},
#     {'x': 1024, 'y': 574},
#     {'x': 1024, 'y': 650},
#     {'x': 164, 'y': 650}],
#    'category': 'paragraph',
#    'html': "<p id='4' data-category='paragraph' style='font-size:16px'>* 고객이 위협이나 강박상태에 있는 등 의심할 만한 정황이 있는 경우 다른 비대면 방식을<br>통한 추가 확인이나 대면확인 요구 가능</p>",
#    'id': 1259,
#    'page': 131,
#    'text': '* 고객이 위협이나 강박상태에 있는 등 의심할 만한 정황이 있는 경우 다른 비대면 방식을\n통한 추가 확인이나 대면확인 요구 가능'},
#   {'bounding_box': [{'x': 127, 'y': 698},
#     {'x': 1023, 'y': 698},
#     {'x': 1023, 'y': 780},
#     {'x': 127, 'y': 780}],
#    'category': 'list',
#    'html': "<p id='5' data-category='list' style='font-size:20px'>③ 접근매체 전달과정에서 확인 본인만 수취할 수 있는 우편 등을 통해 고객에게 현금카드,<br>통장, OTP, 보안카드 등 접근매체 전달과정에서 실명확인증표 확인</p>",
#    'id': 1260,
#    'page': 131,
#    'text': '③ 접근매체 전달과정에서 확인 본인만 수취할 수 있는 우편 등을 통해 고객에게 현금카드,\n통장, OTP, 보안카드 등 접근매체 전달과정에서 실명확인증표 확인'},
#   {'bounding_box': [{'x': 127, 'y': 827},
#     {'x': 1029, 'y': 827},
#     {'x': 1029, 'y': 910},
#     {'x': 127, 'y': 910}],
#    'category': 'list',
#    'html': "<p id='6' data-category='list' style='font-size:18px'>④ 기존계좌 활용 : 타 금융회사에 이미 개설되어있는 고객의 기존계좌로부터 금융회사가<br>소액이체를 받는 등의 방식*을 통해 고객이 동 계좌에 대해 사용권한이 있는지 확인</p>",
#    'id': 1261,
#    'page': 131,
#    'text': '④ 기존계좌 활용 : 타 금융회사에 이미 개설되어있는 고객의 기존계좌로부터 금융회사가\n소액이체를 받는 등의 방식*을 통해 고객이 동 계좌에 대해 사용권한이 있는지 확인'},
#   {'bounding_box': [{'x': 161, 'y': 957},
#     {'x': 1027, 'y': 957},
#     {'x': 1027, 'y': 1074},
#     {'x': 161, 'y': 1074}],
#    'category': 'paragraph',
#    'html': "<p id='7' data-category='paragraph' style='font-size:16px'>* 예 : ①고객이 금융회사가 지정한 금액을 이체, ②금융회사가 기존 계좌에 소액이체 후<br>고객이 해당 자금을 금융회사에 재이체, ③고객의 기존 계좌에 대해 금융회사가 소액이체<br>등의 방식을 통해 1회용 인증번호 등을 전송하고 고객이 해당 인증번호를 입력하는 방법 등</p>",
#    'id': 1262,
#    'page': 131,
#    'text': '* 예 : ①고객이 금융회사가 지정한 금액을 이체, ②금융회사가 기존 계좌에 소액이체 후\n고객이 해당 자금을 금융회사에 재이체, ③고객의 기존 계좌에 대해 금융회사가 소액이체\n등의 방식을 통해 1회용 인증번호 등을 전송하고 고객이 해당 인증번호를 입력하는 방법 등'},
#   {'bounding_box': [{'x': 126, 'y': 1122},
#     {'x': 1026, 'y': 1122},
#     {'x': 1026, 'y': 1201},
#     {'x': 126, 'y': 1201}],
#    'category': 'paragraph',
#    'html': '<p id=\'8\' data-category=\'paragraph\' style=\'font-size:18px\'>⑤ 기타 이에 준하는 방법 * : 금융회사에 생체정보**(이하 "바이오정보"라 한다)를 등록한<br>고객은 사전에 대면 ·비대면 등으로 등록한 바이오정보와 비교를 통해 확인</p>',
#    'id': 1263,
#    'page': 131,
#    'text': '⑤ 기타 이에 준하는 방법 * : 금융회사에 생체정보**(이하 "바이오정보"라 한다)를 등록한\n고객은 사전에 대면 ·비대면 등으로 등록한 바이오정보와 비교를 통해 확인'},
#   {'bounding_box': [{'x': 170, 'y': 1250},
#     {'x': 1024, 'y': 1250},
#     {'x': 1024, 'y': 1405},
#     {'x': 170, 'y': 1405}],
#    'category': 'list',
#    'html': "<p id='9' data-category='list' style='font-size:16px'>* 바이오정보 외에 새로운 방식의 실명확인 방안에 대한 금융위원회의 승인은 불필요하고,<br>금융회사가 자체적으로 판단하여 적용 가능<br>** 지문, 정맥, 얼굴(안면), 홍채, 음성, 서명, 키스트로크, 보행 등 개인의 신체적 또는 행동적<br>특징을 디지털화한 정보</p>",
#    'id': 1264,
#    'page': 131,
#    'text': '* 바이오정보 외에 새로운 방식의 실명확인 방안에 대한 금융위원회의 승인은 불필요하고,\n금융회사가 자체적으로 판단하여 적용 가능\n** 지문, 정맥, 얼굴(안면), 홍채, 음성, 서명, 키스트로크, 보행 등 개인의 신체적 또는 행동적\n특징을 디지털화한 정보'},
#   {'bounding_box': [{'x': 788, 'y': 1481},
#     {'x': 1027, 'y': 1481},
#     {'x': 1027, 'y': 1507},
#     {'x': 788, 'y': 1507}],
#    'category': 'footer',
#    'html': "<footer id='10' style='font-size:14px'>Financial Security Institute 123</footer>",
#    'id': 1265,
#    'page': 131,
#    'text': 'Financial Security Institute 123'}],
#  132: [{'bounding_box': [{'x': 129, 'y': 142},
#     {'x': 401, 'y': 142},
#     {'x': 401, 'y': 169},
#     {'x': 129, 'y': 169}],
#    'category': 'paragraph',
#    'html': "<p id='0' data-category='paragraph' style='font-size:16px'>금융분야 마이데이터 기술 가이드라인</p>",
#    'id': 1266,
#    'page': 132,
#    'text': '금융분야 마이데이터 기술 가이드라인'},
#   {'bounding_box': [{'x': 130, 'y': 227},
#     {'x': 1027, 'y': 227},
#     {'x': 1027, 'y': 306},
#     {'x': 130, 'y': 306}],
#    'category': 'paragraph',
#    'html': "<p id='1' data-category='paragraph' style='font-size:20px'>⑥ 타 기관 확인결과 활용 : 신용카드, 공동인증서, 아이핀(I-PIN), 휴대폰과 같이 인증<br>기관 등에서 신분확인 후 발급한 파일, 아이디 · 비밀번호, 전화번호 활용</p>",
#    'id': 1267,
#    'page': 132,
#    'text': '⑥ 타 기관 확인결과 활용 : 신용카드, 공동인증서, 아이핀(I-PIN), 휴대폰과 같이 인증\n기관 등에서 신분확인 후 발급한 파일, 아이디 · 비밀번호, 전화번호 활용'},
#   {'bounding_box': [{'x': 126, 'y': 357},
#     {'x': 1025, 'y': 357},
#     {'x': 1025, 'y': 435},
#     {'x': 126, 'y': 435}],
#    'category': 'paragraph',
#    'html': "<p id='2' data-category='paragraph' style='font-size:20px'>⑦ 다수의 고객정보 검증 : 고객이 제공하는 정보(예 : 전화번호, 주소, 이메일, 직장정보<br>등)와 신용정보회사 등이 보유한 정보를 대조</p>",
#    'id': 1268,
#    'page': 132,
#    'text': '⑦ 다수의 고객정보 검증 : 고객이 제공하는 정보(예 : 전화번호, 주소, 이메일, 직장정보\n등)와 신용정보회사 등이 보유한 정보를 대조'},
#   {'bounding_box': [{'x': 131, 'y': 1479},
#     {'x': 253, 'y': 1479},
#     {'x': 253, 'y': 1507},
#     {'x': 131, 'y': 1507}],
#    'category': 'footer',
#    'html': "<footer id='3' style='font-size:14px'>124 금융보안원</footer>",
#    'id': 1269,
#    'page': 132,
#    'text': '124 금융보안원'}],
#  133: [{'bounding_box': [{'x': 130, 'y': 228},
#     {'x': 933, 'y': 228},
#     {'x': 933, 'y': 270},
#     {'x': 130, 'y': 270}],
#    'category': 'heading1',
#    'html': "<h1 id='0' style='font-size:20px'>참고 5. 마이데이터 정보제공자용 접근토큰 관리 자체점검표</h1>",
#    'id': 1270,
#    'page': 133,
#    'text': '참고 5. 마이데이터 정보제공자용 접근토큰 관리 자체점검표'},
#   {'bounding_box': [{'x': 135, 'y': 319},
#     {'x': 1023, 'y': 319},
#     {'x': 1023, 'y': 1292},
#     {'x': 135, 'y': 1292}],
#    'category': 'table',
#    'html': '<table id=\'1\' style=\'font-size:16px\'><tr><td></td><td>점검항목</td><td>점검결과 (O/X)</td></tr><tr><td rowspan="6">1.규격 및 유효기간</td><td>1-1. 접근토큰 표준 규격(JWS)을 준용</td><td></td></tr><tr><td>1-2. 리프레시토큰의 유효기간을 실제 전송요구 종료시점과 같거나 길게 설정하여 발급</td><td></td></tr><tr><td>1-3. 정보제공API 접근토큰의 유효기간을 90일 이내로 설정하여 발급</td><td></td></tr><tr><td>1-4. 정보제공API 리프레시토큰의 유효기간을 1년 이내로 설정하여 발급</td><td></td></tr><tr><td>1-5. 지원API 제공용 접근토큰의 유효기간을 1년 이내로 설정하여 발급</td><td></td></tr><tr><td>1-6. 접근토큰 발급·재발급 시 전송요구 동의기간을 참고하여 유효기간을 알맞게 설정하여 발급</td><td></td></tr><tr><td rowspan="5">2.발급관리</td><td>2-1. 실제로 전송을 요구한 정보주체에 해당하는 접근토큰과 리프레시토큰을 발급</td><td></td></tr><tr><td>2-2. 정보주체별로 중복된 접근토큰과 리프레시토큰이 발급되지 않도록 발급시 확인 · 관리</td><td></td></tr><tr><td>시) 인가코드 발급 시 client_id, redirect_uri 검증을 수행 2-3. (개별인증</td><td></td></tr><tr><td>2-4. (개별인증 시) 인가코드의 유효시간 10분 이내로 설정</td><td></td></tr><tr><td>2-5. 동일 정보제공자라 하더라도 복수개의 업권에 대해서 각 업권별로 접근 토큰을 발급·관리</td><td></td></tr><tr><td rowspan="3">3.갱신 및 폐기관리</td><td>3-1. 전송요구 유효기간 동안 리프레시토큰을 무단 변경하지 않음 (갱신·삭제 등)</td><td></td></tr><tr><td>3-2. 전송요구 변경에 따라 새로운 접근토큰과 리프레시토큰 발급 시 기존 접근 토큰과 리프레시토큰을 즉시 폐기</td><td></td></tr><tr><td>3-3. 전송요구 철회시 접근토큰과 리프레시토큰을 즉시 폐기</td><td></td></tr><tr><td rowspan="2">4. 정보제공</td><td>4-1. 정보제공 API 응답시 타인의 정보가 제공되지 않도록 접근토큰 중복여부, 유효 성을 검증</td><td></td></tr><tr><td>4-2. 전송요구 기한 만료 이후 정보제공 API 응답이 이루어지지 않도록 전송요구 종료시 점을 검증(40106 에러코드 관련)</td><td></td></tr></table>',
#    'id': 1271,
#    'page': 133,
#    'text': '점검항목 점검결과 (O/X)\n 1.규격 및 유효기간 1-1. 접근토큰 표준 규격(JWS)을 준용 \n 1-2. 리프레시토큰의 유효기간을 실제 전송요구 종료시점과 같거나 길게 설정하여 발급 \n 1-3. 정보제공API 접근토큰의 유효기간을 90일 이내로 설정하여 발급 \n 1-4. 정보제공API 리프레시토큰의 유효기간을 1년 이내로 설정하여 발급 \n 1-5. 지원API 제공용 접근토큰의 유효기간을 1년 이내로 설정하여 발급 \n 1-6. 접근토큰 발급·재발급 시 전송요구 동의기간을 참고하여 유효기간을 알맞게 설정하여 발급 \n 2.발급관리 2-1. 실제로 전송을 요구한 정보주체에 해당하는 접근토큰과 리프레시토큰을 발급 \n 2-2. 정보주체별로 중복된 접근토큰과 리프레시토큰이 발급되지 않도록 발급시 확인 · 관리 \n 시) 인가코드 발급 시 client_id, redirect_uri 검증을 수행 2-3. (개별인증 \n 2-4. (개별인증 시) 인가코드의 유효시간 10분 이내로 설정 \n 2-5. 동일 정보제공자라 하더라도 복수개의 업권에 대해서 각 업권별로 접근 토큰을 발급·관리 \n 3.갱신 및 폐기관리 3-1. 전송요구 유효기간 동안 리프레시토큰을 무단 변경하지 않음 (갱신·삭제 등) \n 3-2. 전송요구 변경에 따라 새로운 접근토큰과 리프레시토큰 발급 시 기존 접근 토큰과 리프레시토큰을 즉시 폐기 \n 3-3. 전송요구 철회시 접근토큰과 리프레시토큰을 즉시 폐기 \n 4. 정보제공 4-1. 정보제공 API 응답시 타인의 정보가 제공되지 않도록 접근토큰 중복여부, 유효 성을 검증 \n 4-2. 전송요구 기한 만료 이후 정보제공 API 응답이 이루어지지 않도록 전송요구 종료시 점을 검증(40106 에러코드 관련)'},
#   {'bounding_box': [{'x': 788, 'y': 1480},
#     {'x': 1027, 'y': 1480},
#     {'x': 1027, 'y': 1507},
#     {'x': 788, 'y': 1507}],
#    'category': 'footer',
#    'html': "<footer id='2' style='font-size:14px'>Financial Security Institute 125</footer>",
#    'id': 1272,
#    'page': 133,
#    'text': 'Financial Security Institute 125'}],
#  134: [{'bounding_box': [{'x': 222, 'y': 764},
#     {'x': 938, 'y': 764},
#     {'x': 938, 'y': 1217},
#     {'x': 222, 'y': 1217}],
#    'category': 'figure',
#    'html': '<figure><img id=\'0\' style=\'font-size:14px\' alt="금융분야 마이데이터 기술 가이드라인\n발 행 일 2021년 2월 23일\n발 행 처 금융보안원\n(16881) 경기도 용인시 수지구 대지로 132\nT. 02-3495-9000\n디자인 · 인쇄 경성문화사\nT. 02-786-2999\n※ 본 가이드라인의 임의 복제·복사 및 판매를 금지합니다." data-coord="top-left:(222,764); bottom-right:(938,1217)" /></figure>',
#    'id': 1273,
#    'page': 134,
#    'text': '금융분야 마이데이터 기술 가이드라인\n발 행 일 2021년 2월 23일\n발 행 처 금융보안원\n(16881) 경기도 용인시 수지구 대지로 132\nT. 02-3495-9000\n디자인 · 인쇄 경성문화사\nT. 02-786-2999\n※ 본 가이드라인의 임의 복제·복사 및 판매를 금지합니다.'}]}
